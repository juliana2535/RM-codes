# %%
#The MIT License (MIT)

#Copyright (c) 2020 Juliana T.C. Marcos

#THE SOFTWARE IS PROVIDED "AS IS", WITHOUT WARRANTY OF ANY KIND, EXPRESS OR IMPLIED, INCLUDING BUT NOT LIMITED TO
#THE WARRANTIES OF MERCHANTABILITY, FITNESS FOR A PARTICULAR PURPOSE AND NONINFRINGEMENT. IN NO EVENT SHALL THE 
#AUTHORS OR COPYRIGHT HOLDERS BE LIABLE FOR ANY CLAIM, DAMAGES OR OTHER LIABILITY, WHETHER IN AN ACTION OF 
#CONTRACT, TORT OR OTHERWISE, ARISING FROM, OUT OF OR IN CONNECTION WITH THE SOFTWARE OR THE USE OR OTHER DEALINGS IN THE SOFTWARE.

#This code use methods of the ParticleFilter (PF) class in order to track an object in a video. The PF uses two
#measurements providers which are intermitently chosen based on the value of the ssim index of two images. The
#first image is a template of the animal to track while the second is the Region of Interest (ROI) surrounding
#the previous estimated location of the tracked animal. The measurements providers are a colour image segmentation
#technique and  one of the 8 trackers implemented in opencv. The relevant OpenCV's tracker continue to update during
#the colour image segmentation call but without providing any measurement.

#The particles are represented in red, the PF estimate of
#the tracked animal is represented in green and the animal's bb is represented in blue.

# %%
#Import of useful librairies
import math
import numpy as np
from skimage import measure
from ParticleFilter import ParticleFilter
import cv2
import time

# %%
#tracker = "BOOSTING"
tracker = "KCF"
#tracker = "CSRT"
#tracker = "MOSSE"
#tracker = "TLD"
#tracker = "MIL"
#tracker = "MEDIANFLOW"
#tracker = "GOTURN"

# %%
"""Some variables initialization """

#Number of trials to average
Tot=1
#Lists for the Tot running outputs averages 
BB_avg=[]
anchor_avg=[]
xy_est_avg=[]
ssim_avg=[]
particles_avg=[]
#Video frame width and height
frame_width=1920
frame_height=1080
#number of particles
n_particles=2000
#noise in sensors' measurements
meas_noise=0
#Initialization of some important variables
font = cv2.FONT_HERSHEY_SIMPLEX
text_coord=(10,40)
t_size=0.8
t_thick=2
ssim=0
#This value was chosen according to a paper experiment
N_thresh=(2*n_particles)/30
n_resampling=0
#Lists to contain the counters for each trial
cis_l=[]
track_call_l=[]
track_ctr_l=[]
n_resampl_l=[]
#Initialize variable for shifting the anchor update between first measurements and first estimations
anchor_shift=60

# %%
#Data for video cows
anchorS=(1250,350)
#This threshold helps to filter small contours
#It is however important to adapt it to the object scales in the videos
Area_thresh=0
#This is to choose the type of threshold (between cv2.THRESH_BINARY_INV 
#and THRESH_BINARY)
#for Dark or bright template
type_thr=cv2.THRESH_BINARY_INV
#type_thr=cv2.THRESH_BINARY
#std in the prediction of particles for the object's position
std=10
#Capture video where object tracking should be performed
videoIn_name="./Inputs/cows.avi"
path="./Outputs/"
videoOut_name=path+"cows-pf-ssim-colour-"+tracker+".avi"
template = cv2.imread('./Inputs/template2.png')
template2 = cv2.imread('./Inputs/template2_grass.png')
chg_thres=0.6
height, width =120,260
#Motion model's speed in x and y directions
v_x=0.01
v_y=0.01

# %%
fyi,fxi=template2.shape[0],template2.shape[1]

# %%
start_time = time.time()
for num in range(Tot):
    #List for averaging running outputs
    BB_l=[]
    anchor_l=[]
    xy_est_l=[]
    ssim_l=[]
    particles_l=[]
    #Counters
    cis=0
    track_call=0
    track_ctr=0
    it=0
    n_resampling=0
    #A single program variables initialization
    anchor=anchorS
    #Initialization of measurements variables
    x_objMeasure,y_objMeasure=anchor[0],anchor[1]
    #Initialization of some important variables
    ssim=0
    #BB variable initialization
    BB=0,0,0,0
    BB_t=0,0,0,0
    #Capture video where object tracking should be performed
    video = cv2.VideoCapture(videoIn_name)
    #Video output
    fourcc = cv2.VideoWriter_fourcc(*'XVID')
    video_output = cv2.VideoWriter(videoOut_name,fourcc,60,(frame_width,frame_height))
    #Particles Instantiation
    particles=ParticleFilter(frame_width,frame_height, n_particles)
    
    if tracker == "BOOSTING":
        track = cv2.TrackerBoosting_create()
    elif tracker == "KCF":
        track = cv2.TrackerKCF_create()
    elif tracker == "MIL":
        track = cv2.TrackerMIL_create()
    elif tracker == "MOSSE":
        track = cv2.TrackerMOSSE_create()
    elif tracker == "TLD":
        track = cv2.TrackerTLD_create()
    elif tracker == "CSRT":
        track = cv2.TrackerCSRT_create()
    elif tracker == "MEDIANFLOW":
        track = cv2.TrackerMedianFlow_create()
    else :
        track = cv2.TrackerGOTURN_create()

    
    #This function uses opencv functions to identify the center of the animal to track
    def sensors_measurements(template,img,anchor,meas_noise=3,kernel=3):

        #Compute the mean color of the template containing the animal to track color
        meanStdTemplate=cv2.meanStdDev(template)

        #Convert the color of the frame to work on and apply the GaussianBlur function in order to remove
        #Gaussian noise, smooth image and somrtimes highlight edges
        img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        img = cv2.GaussianBlur(img, (kernel, kernel), 0)

        #Binarize frame using the color mean of the animal in such a way that matching parts
        #of the frame will appear white and other parts will appear black
        ret,thresh = cv2.threshold(img,meanStdTemplate[0][1],255,type_thr)

        # find contours in the thresholded image. The if condition is used to avoid error that happens depending
        #on the python version used. The middle parameter is to only retrieve parent contours while the latter
        #is to avoid redundant points in contours.
        cnts = cv2.findContours(thresh.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        contours = cnts[0] if len(cnts) == 2 else cnts[1]

        #Compute the contours areas
        contoursAreas=[cv2.contourArea(c) for c in contours]

        #Compute the center and the BB of the contours
        contoursCenter=[]
        contoursBB=[]

        for c in range(len(contours)):
            M = cv2.moments(contours[c])
            #If the area of the current contour exists and is greater than a threshold for areas 
            if M["m00"] != 0 and contoursAreas[c]>Area_thresh:
                cX = int(M["m10"] / M["m00"])
                cY = int(M["m01"] / M["m00"])
                contoursCenter.append((c,cX,cY,contoursAreas[c]))
                contoursBB.append(cv2.boundingRect(contours[c]))

        #Compute the distance between each center and the anchor center in order to find 
        #the most suitable shape to track i.e the closest one to the anchor

        contoursAnchorDist=[math.sqrt((contoursCenter[i][1]-anchor[0])**2+\
        (contoursCenter[i][2]-anchor[1])**2) for i in range (len(contoursCenter))]

        #Save and return the coordinates of the most suitable center and its contours
        index=contoursAnchorDist.index(min(contoursAnchorDist))
        cX=contoursCenter[index][1]+np.random.standard_normal()*meas_noise
        cY=contoursCenter[index][2]+np.random.standard_normal()*meas_noise

        return cX,cY,contoursBB[index]

    #Loop through the entire video
    while (True):
        #Take the video and break it frame by frame
        _,frame=video.read()
        #Check if frames are captured
        if(_ == False ): break

        it+=1
        
        #initialization of opencv tracker
        if it==1 and _==True:
            BB_t=(int(anchor[0]-width/2),int(anchor[1]-height/2),width,height)
            track.init(frame,BB_t)
            
        #Particles prediction update
        particles.particles_update(v_x,v_y,std,frame_width,frame_height)
        particles_l.append(particles.particles.copy())
        anchor_l.append(anchor)
    
        #Take dimensions of ROI around animal in current frame for SSIM evaluation with 
        #template
        ROI_ssim=(int(anchor[0]-fxi/2),int(anchor[1]-fyi/2),fxi,fyi)
        frame_crop=frame[ROI_ssim[1]:ROI_ssim[1]+ROI_ssim[3],ROI_ssim[0]:ROI_ssim[0]+ROI_ssim[2]]
        fy,fx=frame_crop.shape[0],frame_crop.shape[1]
    
        #Here, we check if the dimensions of the ROI around the animal and the template are the same
        #to select the cis if not, because these cases correspond to the frame boundaries. Therefore, 
        #the ROI might not contain sufficient information to allow the change detection with the ssim.
        if ((fxi!=fx) or (fyi!=fy)):
            ssim=1.1
        else: 
            #The value 3 is the minimum dimension for images to compute the ssim index
            if ((fxi>3 and fyi>3)): 
                ssim=measure.compare_ssim(frame_crop,template2, \
                                              multichannel=True,win_size=3)
            else:
                ssim=0.0
        
        ssim=abs(ssim)
        ssim_l.append(ssim)
        
        if (ssim<chg_thres):
            track_call+=1
            #If a potential change is detected, call a method other than the cis to provide measurements to the PF
            cont, BB_t = track.update(frame)
            if cont==True:
                x_objMeasure,y_objMeasure=BB_t[0]+BB_t[2]/2,BB_t[1]+BB_t[3]/2
                BB=int(BB_t[0]),int(BB_t[1]),int(BB_t[2]),int(BB_t[3])
                track_ctr+=1
                print("step: ",it," x_objMeasure ",x_objMeasure," y_objMeasure ",y_objMeasure," BB_t ",BB_t)

            cv2.putText(frame,'Change detected call '+tracker+' : SSIM = '+str(ssim),text_coord,font,t_size,(255,255,255),t_thick,cv2.LINE_AA)
            
        else :
            #Measurements
            x_objMeasure,y_objMeasure,BB = sensors_measurements(template,frame,anchor,meas_noise) 
            cis+=1
            print("step: ",it," x_objMeasure ",x_objMeasure," y_objMeasure ",y_objMeasure," BB ",BB)

            cv2.putText(frame,'No Change detected, use CIS: SSIM = '+str(ssim),text_coord,font,t_size,(255,255,255),t_thick,cv2.LINE_AA)   
            #Run the other measurement provider in parallel without taking its measurements, since some
            #of the potential cis relay strongly depend on learning the target appearance.
            cont, BB_t = track.update(frame)
            
        #Save BB in a list and anchor in another list
        BB_l.append(BB)
        
        #Update the particles weights with the new measurement
        particles.weigth_update(x_objMeasure,y_objMeasure)

        #Estimation of object center position
        x_estimation,y_estimation=particles.position_estimation()
        print("step: ",it," x_estimation ",x_estimation," y_estimation ",y_estimation)
        
        #Save the x and y estimated in a list
        xy_est_l.append((x_estimation,y_estimation))

        #Draw the particles
        particles.draw_box_particles(frame,BB,x_estimation,y_estimation)
        #Draw the position estimation
        cv2.circle(frame,(x_estimation,y_estimation),5,[0,255,0],3)

        #Update the anchor with either the current measurements or the x and y estimates
        if it > anchor_shift:
            anchor=x_estimation,y_estimation
        else:
            anchor=x_objMeasure,y_objMeasure
        
        #Resample the particles

        if (particles.effective_particles() < N_thresh):
            n_resampling+=1
            particles.resampling()

        if (num==Tot-1):
            video_output.write(frame)
            
        #Reinitialize BB to avoid cis' bb drawing when the tracker does not track
        BB=0,0,0,0

        #if it==50:
        #    break
        
    #List for the number of resampling, cis counters,track_call and track_ctr    
    n_resampl_l.append(n_resampling)
    cis_l.append(cis)
    track_call_l.append(track_call)
    track_ctr_l.append(track_ctr)
    BB_avg.append(BB_l)
    xy_est_avg.append(xy_est_l)
    ssim_avg.append(ssim_l)
    particles_avg.append(particles_l)
    anchor_avg.append(anchor_l)
# Out:
# step:  1  x_objMeasure  1250.0  y_objMeasure  364.0  BB  (1115, 296, 269, 131)
# step:  1  x_estimation  1117  y_estimation  468
# step:  2  x_objMeasure  1252.0  y_objMeasure  364.0  BB  (1115, 296, 269, 131)
# step:  2  x_estimation  1228  y_estimation  393
# step:  3  x_objMeasure  1252.0  y_objMeasure  364.0  BB  (1115, 296, 268, 132)
# step:  3  x_estimation  1273  y_estimation  350
# step:  4  x_objMeasure  1252.0  y_objMeasure  365.0  BB  (1115, 296, 268, 132)
# step:  4  x_estimation  1268  y_estimation  352
# step:  5  x_objMeasure  1252.0  y_objMeasure  365.0  BB  (1115, 297, 269, 131)
# step:  5  x_estimation  1260  y_estimation  357
# step:  6  x_objMeasure  1252.0  y_objMeasure  365.0  BB  (1115, 297, 269, 131)
# step:  6  x_estimation  1251  y_estimation  364
# step:  7  x_objMeasure  1252.0  y_objMeasure  365.0  BB  (1115, 297, 269, 131)
# step:  7  x_estimation  1251  y_estimation  363
# step:  8  x_objMeasure  1252.0  y_objMeasure  365.0  BB  (1114, 297, 272, 131)
# step:  8  x_estimation  1252  y_estimation  364
# step:  9  x_objMeasure  1254.0  y_objMeasure  366.0  BB  (1116, 307, 270, 121)
# step:  9  x_estimation  1254  y_estimation  365
# step:  10  x_objMeasure  1254.0  y_objMeasure  366.0  BB  (1116, 308, 271, 120)
# step:  10  x_estimation  1254  y_estimation  365
# step:  11  x_objMeasure  1254.0  y_objMeasure  366.0  BB  (1115, 308, 272, 120)
# step:  11  x_estimation  1254  y_estimation  365
# step:  12  x_objMeasure  1253.0  y_objMeasure  366.0  BB  (1115, 308, 272, 120)
# step:  12  x_estimation  1253  y_estimation  365
# step:  13  x_objMeasure  1252.0  y_objMeasure  366.0  BB  (1113, 298, 275, 130)
# step:  13  x_estimation  1252  y_estimation  365
# step:  14  x_objMeasure  1252.0  y_objMeasure  366.0  BB  (1113, 298, 275, 130)
# step:  14  x_estimation  1251  y_estimation  366
# step:  15  x_objMeasure  1251.0  y_objMeasure  367.0  BB  (1112, 299, 277, 130)
# step:  15  x_estimation  1251  y_estimation  366
# step:  16  x_objMeasure  1251.0  y_objMeasure  366.0  BB  (1112, 299, 277, 130)
# step:  16  x_estimation  1250  y_estimation  367
# step:  17  x_objMeasure  1251.0  y_objMeasure  367.0  BB  (1112, 299, 277, 130)
# step:  17  x_estimation  1251  y_estimation  367
# step:  18  x_objMeasure  1251.0  y_objMeasure  367.0  BB  (1112, 299, 277, 130)
# step:  18  x_estimation  1250  y_estimation  366
# step:  19  x_objMeasure  1250.0  y_objMeasure  367.0  BB  (1111, 299, 276, 131)
# step:  19  x_estimation  1250  y_estimation  366
# step:  20  x_objMeasure  1249.0  y_objMeasure  367.0  BB  (1111, 299, 276, 132)
# step:  20  x_estimation  1249  y_estimation  367
# step:  21  x_objMeasure  1249.0  y_objMeasure  367.0  BB  (1111, 299, 274, 132)
# step:  21  x_estimation  1249  y_estimation  367
# step:  22  x_objMeasure  1249.0  y_objMeasure  368.0  BB  (1111, 300, 273, 131)
# step:  22  x_estimation  1248  y_estimation  366
# step:  23  x_objMeasure  1248.0  y_objMeasure  368.0  BB  (1111, 300, 273, 132)
# step:  23  x_estimation  1248  y_estimation  367
# step:  24  x_objMeasure  1248.0  y_objMeasure  368.0  BB  (1110, 300, 273, 132)
# step:  24  x_estimation  1248  y_estimation  368
# step:  25  x_objMeasure  1248.0  y_objMeasure  370.0  BB  (1114, 322, 269, 110)
# step:  25  x_estimation  1248  y_estimation  368
# step:  26  x_objMeasure  1248.0  y_objMeasure  371.0  BB  (1113, 322, 271, 110)
# step:  26  x_estimation  1248  y_estimation  370
# step:  27  x_objMeasure  1248.0  y_objMeasure  371.0  BB  (1113, 322, 271, 110)
# step:  27  x_estimation  1248  y_estimation  370
# step:  28  x_objMeasure  1248.0  y_objMeasure  371.0  BB  (1113, 322, 272, 110)
# step:  28  x_estimation  1247  y_estimation  370
# step:  29  x_objMeasure  1248.0  y_objMeasure  371.0  BB  (1113, 322, 272, 110)
# step:  29  x_estimation  1247  y_estimation  371
# step:  30  x_objMeasure  1248.0  y_objMeasure  371.0  BB  (1113, 322, 272, 110)
# step:  30  x_estimation  1247  y_estimation  371
# step:  31  x_objMeasure  1250.0  y_objMeasure  370.0  BB  (1113, 311, 271, 121)
# step:  31  x_estimation  1249  y_estimation  370
# step:  32  x_objMeasure  1250.0  y_objMeasure  370.0  BB  (1111, 311, 273, 121)
# step:  32  x_estimation  1250  y_estimation  369
# step:  33  x_objMeasure  1250.0  y_objMeasure  371.0  BB  (1111, 311, 272, 121)
# step:  33  x_estimation  1249  y_estimation  370
# step:  34  x_objMeasure  1250.0  y_objMeasure  370.0  BB  (1110, 311, 272, 121)
# step:  34  x_estimation  1249  y_estimation  370
# step:  35  x_objMeasure  1250.0  y_objMeasure  371.0  BB  (1110, 311, 272, 121)
# step:  35  x_estimation  1249  y_estimation  370
# step:  36  x_objMeasure  1249.0  y_objMeasure  371.0  BB  (1110, 311, 272, 121)
# step:  36  x_estimation  1249  y_estimation  371
# step:  37  x_objMeasure  1249.0  y_objMeasure  371.0  BB  (1111, 312, 272, 121)
# step:  37  x_estimation  1249  y_estimation  370
# step:  38  x_objMeasure  1249.0  y_objMeasure  371.0  BB  (1111, 312, 272, 121)
# step:  38  x_estimation  1249  y_estimation  371
# step:  39  x_objMeasure  1249.0  y_objMeasure  372.0  BB  (1110, 313, 273, 120)
# step:  39  x_estimation  1249  y_estimation  372
# step:  40  x_objMeasure  1249.0  y_objMeasure  372.0  BB  (1110, 313, 273, 121)
# step:  40  x_estimation  1248  y_estimation  372
# step:  41  x_objMeasure  1248.0  y_objMeasure  372.0  BB  (1110, 313, 272, 121)
# step:  41  x_estimation  1247  y_estimation  372
# step:  42  x_objMeasure  1248.0  y_objMeasure  372.0  BB  (1110, 313, 271, 121)
# step:  42  x_estimation  1247  y_estimation  372
# step:  43  x_objMeasure  1248.0  y_objMeasure  372.0  BB  (1111, 313, 269, 122)
# step:  43  x_estimation  1247  y_estimation  372
# step:  44  x_objMeasure  1248.0  y_objMeasure  372.0  BB  (1111, 313, 268, 122)
# step:  44  x_estimation  1247  y_estimation  371
# step:  45  x_objMeasure  1248.0  y_objMeasure  373.0  BB  (1111, 314, 268, 121)
# step:  45  x_estimation  1247  y_estimation  372
# step:  46  x_objMeasure  1249.0  y_objMeasure  373.0  BB  (1110, 314, 269, 121)
# step:  46  x_estimation  1248  y_estimation  372
# step:  47  x_objMeasure  1249.0  y_objMeasure  374.0  BB  (1111, 314, 269, 121)
# step:  47  x_estimation  1248  y_estimation  373
# step:  48  x_objMeasure  1249.0  y_objMeasure  374.0  BB  (1111, 315, 270, 120)
# step:  48  x_estimation  1248  y_estimation  374
# step:  49  x_objMeasure  1250.0  y_objMeasure  373.0  BB  (1110, 315, 272, 119)
# step:  49  x_estimation  1248  y_estimation  373
# step:  50  x_objMeasure  1250.0  y_objMeasure  373.0  BB  (1110, 315, 274, 119)
# step:  50  x_estimation  1250  y_estimation  372
# step:  51  x_objMeasure  1251.0  y_objMeasure  373.0  BB  (1110, 315, 274, 119)
# step:  51  x_estimation  1250  y_estimation  372
# step:  52  x_objMeasure  1251.0  y_objMeasure  373.0  BB  (1110, 315, 274, 119)
# step:  52  x_estimation  1250  y_estimation  373
# step:  53  x_objMeasure  1251.0  y_objMeasure  373.0  BB  (1110, 315, 274, 119)
# step:  53  x_estimation  1250  y_estimation  374
# step:  54  x_objMeasure  1248.0  y_objMeasure  373.0  BB  (1108, 305, 276, 129)
# step:  54  x_estimation  1249  y_estimation  374
# step:  55  x_objMeasure  1249.0  y_objMeasure  373.0  BB  (1108, 305, 276, 129)
# step:  55  x_estimation  1249  y_estimation  374
# step:  56  x_objMeasure  1248.0  y_objMeasure  373.0  BB  (1108, 305, 276, 130)
# step:  56  x_estimation  1248  y_estimation  372
# step:  57  x_objMeasure  1248.0  y_objMeasure  373.0  BB  (1109, 306, 275, 129)
# step:  57  x_estimation  1248  y_estimation  373
# step:  58  x_objMeasure  1248.0  y_objMeasure  374.0  BB  (1109, 306, 275, 129)
# step:  58  x_estimation  1247  y_estimation  373
# step:  59  x_objMeasure  1248.0  y_objMeasure  374.0  BB  (1109, 306, 275, 129)
# step:  59  x_estimation  1247  y_estimation  373
# step:  60  x_objMeasure  1248.0  y_objMeasure  374.0  BB  (1109, 306, 275, 129)
# step:  60  x_estimation  1247  y_estimation  374
# step:  61  x_objMeasure  1248.0  y_objMeasure  374.0  BB  (1109, 307, 275, 128)
# step:  61  x_estimation  1248  y_estimation  374
# step:  62  x_objMeasure  1248.0  y_objMeasure  375.0  BB  (1110, 307, 274, 129)
# step:  62  x_estimation  1247  y_estimation  376
# step:  63  x_objMeasure  1248.0  y_objMeasure  375.0  BB  (1110, 307, 273, 130)
# step:  63  x_estimation  1246  y_estimation  375
# step:  64  x_objMeasure  1248.0  y_objMeasure  375.0  BB  (1110, 308, 272, 129)
# step:  64  x_estimation  1247  y_estimation  374
# step:  65  x_objMeasure  1247.0  y_objMeasure  375.0  BB  (1111, 308, 271, 130)
# step:  65  x_estimation  1247  y_estimation  374
# step:  66  x_objMeasure  1249.0  y_objMeasure  375.0  BB  (1111, 308, 270, 130)
# step:  66  x_estimation  1248  y_estimation  374
# step:  67  x_objMeasure  1249.0  y_objMeasure  375.0  BB  (1103, 309, 278, 129)
# step:  67  x_estimation  1248  y_estimation  375
# step:  68  x_objMeasure  1248.0  y_objMeasure  376.0  BB  (1112, 309, 269, 129)
# step:  68  x_estimation  1249  y_estimation  374
# step:  69  x_objMeasure  1248.0  y_objMeasure  376.0  BB  (1112, 310, 270, 128)
# step:  69  x_estimation  1247  y_estimation  374
# step:  70  x_objMeasure  1249.0  y_objMeasure  376.0  BB  (1112, 310, 272, 128)
# step:  70  x_estimation  1247  y_estimation  375
# step:  71  x_objMeasure  1251.0  y_objMeasure  376.0  BB  (1112, 311, 273, 126)
# step:  71  x_estimation  1250  y_estimation  375
# step:  72  x_objMeasure  1251.0  y_objMeasure  376.0  BB  (1112, 311, 274, 126)
# step:  72  x_estimation  1250  y_estimation  376
# step:  73  x_objMeasure  1256.0  y_objMeasure  375.0  BB  (1112, 311, 275, 126)
# step:  73  x_estimation  1253  y_estimation  375
# step:  74  x_objMeasure  1256.0  y_objMeasure  375.0  BB  (1112, 311, 276, 126)
# step:  74  x_estimation  1254  y_estimation  375
# step:  75  x_objMeasure  1257.0  y_objMeasure  375.0  BB  (1113, 312, 276, 125)
# step:  75  x_estimation  1257  y_estimation  375
# step:  76  x_objMeasure  1257.0  y_objMeasure  375.0  BB  (1113, 312, 277, 125)
# step:  76  x_estimation  1258  y_estimation  375
# step:  77  x_objMeasure  1258.0  y_objMeasure  376.0  BB  (1114, 313, 276, 125)
# step:  77  x_estimation  1258  y_estimation  376
# step:  78  x_objMeasure  1257.0  y_objMeasure  376.0  BB  (1115, 313, 275, 125)
# step:  78  x_estimation  1257  y_estimation  376
# step:  79  x_objMeasure  1257.0  y_objMeasure  376.0  BB  (1115, 314, 275, 123)
# step:  79  x_estimation  1257  y_estimation  376
# step:  80  x_objMeasure  1257.0  y_objMeasure  376.0  BB  (1116, 314, 275, 124)
# step:  80  x_estimation  1256  y_estimation  376
# step:  81  x_objMeasure  1257.0  y_objMeasure  376.0  BB  (1116, 314, 275, 123)
# step:  81  x_estimation  1257  y_estimation  375
# step:  82  x_objMeasure  1258.0  y_objMeasure  376.0  BB  (1117, 314, 274, 124)
# step:  82  x_estimation  1257  y_estimation  375
# step:  83  x_objMeasure  1258.0  y_objMeasure  376.0  BB  (1117, 314, 273, 124)
# step:  83  x_estimation  1258  y_estimation  376
# step:  84  x_objMeasure  1258.0  y_objMeasure  376.0  BB  (1118, 314, 272, 124)
# step:  84  x_estimation  1257  y_estimation  376
# step:  85  x_objMeasure  1258.0  y_objMeasure  377.0  BB  (1119, 314, 271, 124)
# step:  85  x_estimation  1257  y_estimation  376
# step:  86  x_objMeasure  1258.0  y_objMeasure  377.0  BB  (1119, 314, 271, 124)
# step:  86  x_estimation  1258  y_estimation  377
# step:  87  x_objMeasure  1254.0  y_objMeasure  378.0  BB  (1116, 314, 274, 124)
# step:  87  x_estimation  1256  y_estimation  377
# step:  88  x_objMeasure  1254.0  y_objMeasure  378.0  BB  (1117, 315, 274, 124)
# step:  88  x_estimation  1255  y_estimation  377
# step:  89  x_objMeasure  1254.0  y_objMeasure  378.0  BB  (1118, 315, 273, 124)
# step:  89  x_estimation  1254  y_estimation  377
# step:  90  x_objMeasure  1255.0  y_objMeasure  379.0  BB  (1119, 315, 273, 124)
# step:  90  x_estimation  1255  y_estimation  378
# step:  91  x_objMeasure  1255.0  y_objMeasure  379.0  BB  (1120, 315, 272, 124)
# step:  91  x_estimation  1254  y_estimation  379
# step:  92  x_objMeasure  1255.0  y_objMeasure  379.0  BB  (1121, 316, 271, 124)
# step:  92  x_estimation  1254  y_estimation  379
# step:  93  x_objMeasure  1256.0  y_objMeasure  379.0  BB  (1121, 316, 272, 124)
# step:  93  x_estimation  1255  y_estimation  379
# step:  94  x_objMeasure  1256.0  y_objMeasure  379.0  BB  (1122, 316, 271, 125)
# step:  94  x_estimation  1255  y_estimation  379
# step:  95  x_objMeasure  1258.0  y_objMeasure  379.0  BB  (1122, 316, 271, 125)
# step:  95  x_estimation  1256  y_estimation  379
# step:  96  x_objMeasure  1258.0  y_objMeasure  379.0  BB  (1123, 316, 271, 125)
# step:  96  x_estimation  1258  y_estimation  379
# step:  97  x_objMeasure  1258.0  y_objMeasure  379.0  BB  (1123, 316, 271, 125)
# step:  97  x_estimation  1258  y_estimation  379
# step:  98  x_objMeasure  1258.0  y_objMeasure  380.0  BB  (1124, 316, 270, 125)
# step:  98  x_estimation  1257  y_estimation  378
# step:  99  x_objMeasure  1258.0  y_objMeasure  380.0  BB  (1124, 316, 270, 125)
# step:  99  x_estimation  1257  y_estimation  379
# step:  100  x_objMeasure  1258.0  y_objMeasure  380.0  BB  (1124, 317, 270, 124)
# step:  100  x_estimation  1257  y_estimation  380
# step:  101  x_objMeasure  1258.0  y_objMeasure  380.0  BB  (1124, 317, 270, 125)
# step:  101  x_estimation  1257  y_estimation  380
# step:  102  x_objMeasure  1258.0  y_objMeasure  381.0  BB  (1124, 317, 269, 125)
# step:  102  x_estimation  1256  y_estimation  381
# step:  103  x_objMeasure  1259.0  y_objMeasure  381.0  BB  (1124, 317, 269, 125)
# step:  103  x_estimation  1258  y_estimation  380
# step:  104  x_objMeasure  1259.0  y_objMeasure  381.0  BB  (1124, 317, 269, 125)
# step:  104  x_estimation  1259  y_estimation  380
# step:  105  x_objMeasure  1259.0  y_objMeasure  381.0  BB  (1124, 318, 269, 124)
# step:  105  x_estimation  1258  y_estimation  379
# step:  106  x_objMeasure  1259.0  y_objMeasure  381.0  BB  (1124, 318, 269, 124)
# step:  106  x_estimation  1258  y_estimation  380
# step:  107  x_objMeasure  1259.0  y_objMeasure  382.0  BB  (1123, 318, 270, 125)
# step:  107  x_estimation  1258  y_estimation  381
# step:  108  x_objMeasure  1259.0  y_objMeasure  382.0  BB  (1123, 318, 270, 125)
# step:  108  x_estimation  1258  y_estimation  381
# step:  109  x_objMeasure  1258.0  y_objMeasure  383.0  BB  (1123, 318, 270, 125)
# step:  109  x_estimation  1258  y_estimation  382
# step:  110  x_objMeasure  1258.0  y_objMeasure  383.0  BB  (1123, 318, 270, 125)
# step:  110  x_estimation  1258  y_estimation  382
# step:  111  x_objMeasure  1258.0  y_objMeasure  383.0  BB  (1123, 318, 271, 126)
# step:  111  x_estimation  1258  y_estimation  383
# step:  112  x_objMeasure  1259.0  y_objMeasure  383.0  BB  (1123, 319, 271, 125)
# step:  112  x_estimation  1259  y_estimation  383
# step:  113  x_objMeasure  1258.0  y_objMeasure  383.0  BB  (1124, 319, 270, 125)
# step:  113  x_estimation  1258  y_estimation  382
# step:  114  x_objMeasure  1258.0  y_objMeasure  383.0  BB  (1124, 319, 271, 125)
# step:  114  x_estimation  1257  y_estimation  383
# step:  115  x_objMeasure  1258.0  y_objMeasure  384.0  BB  (1124, 319, 271, 125)
# step:  115  x_estimation  1257  y_estimation  382
# step:  116  x_objMeasure  1258.0  y_objMeasure  384.0  BB  (1124, 320, 272, 125)
# step:  116  x_estimation  1257  y_estimation  383
# step:  117  x_objMeasure  1258.0  y_objMeasure  384.0  BB  (1124, 320, 272, 125)
# step:  117  x_estimation  1257  y_estimation  384
# step:  118  x_objMeasure  1258.0  y_objMeasure  385.0  BB  (1125, 320, 271, 125)
# step:  118  x_estimation  1258  y_estimation  384
# step:  119  x_objMeasure  1258.0  y_objMeasure  385.0  BB  (1125, 320, 270, 125)
# step:  119  x_estimation  1258  y_estimation  384
# step:  120  x_objMeasure  1258.0  y_objMeasure  385.0  BB  (1125, 320, 270, 125)
# step:  120  x_estimation  1258  y_estimation  384
# step:  121  x_objMeasure  1258.0  y_objMeasure  385.0  BB  (1125, 320, 269, 126)
# step:  121  x_estimation  1258  y_estimation  383
# step:  122  x_objMeasure  1258.0  y_objMeasure  385.0  BB  (1125, 320, 268, 126)
# step:  122  x_estimation  1257  y_estimation  384
# step:  123  x_objMeasure  1258.0  y_objMeasure  385.0  BB  (1125, 320, 268, 126)
# step:  123  x_estimation  1257  y_estimation  384
# step:  124  x_objMeasure  1258.0  y_objMeasure  386.0  BB  (1125, 321, 267, 126)
# step:  124  x_estimation  1258  y_estimation  384
# step:  125  x_objMeasure  1258.0  y_objMeasure  386.0  BB  (1124, 321, 268, 126)
# step:  125  x_estimation  1258  y_estimation  385
# step:  126  x_objMeasure  1258.0  y_objMeasure  386.0  BB  (1124, 321, 268, 126)
# step:  126  x_estimation  1257  y_estimation  385
# step:  127  x_objMeasure  1258.0  y_objMeasure  386.0  BB  (1124, 321, 268, 126)
# step:  127  x_estimation  1257  y_estimation  385
# step:  128  x_objMeasure  1258.0  y_objMeasure  386.0  BB  (1124, 321, 269, 126)
# step:  128  x_estimation  1258  y_estimation  386
# step:  129  x_objMeasure  1257.0  y_objMeasure  386.0  BB  (1124, 321, 269, 126)
# step:  129  x_estimation  1257  y_estimation  385
# step:  130  x_objMeasure  1258.0  y_objMeasure  386.0  BB  (1124, 321, 270, 127)
# step:  130  x_estimation  1256  y_estimation  385
# step:  131  x_objMeasure  1258.0  y_objMeasure  387.0  BB  (1123, 322, 271, 126)
# step:  131  x_estimation  1257  y_estimation  385
# step:  132  x_objMeasure  1258.0  y_objMeasure  387.0  BB  (1123, 322, 271, 126)
# step:  132  x_estimation  1258  y_estimation  385
# step:  133  x_objMeasure  1257.0  y_objMeasure  387.0  BB  (1123, 322, 272, 126)
# step:  133  x_estimation  1257  y_estimation  386
# step:  134  x_objMeasure  1257.0  y_objMeasure  387.0  BB  (1123, 322, 272, 126)
# step:  134  x_estimation  1257  y_estimation  385
# step:  135  x_objMeasure  1257.0  y_objMeasure  387.0  BB  (1123, 323, 272, 125)
# step:  135  x_estimation  1257  y_estimation  386
# step:  136  x_objMeasure  1258.0  y_objMeasure  387.0  BB  (1123, 323, 272, 125)
# step:  136  x_estimation  1257  y_estimation  385
# step:  137  x_objMeasure  1257.0  y_objMeasure  388.0  BB  (1123, 323, 272, 126)
# step:  137  x_estimation  1257  y_estimation  386
# step:  138  x_objMeasure  1257.0  y_objMeasure  388.0  BB  (1123, 323, 273, 126)
# step:  138  x_estimation  1256  y_estimation  387
# step:  139  x_objMeasure  1257.0  y_objMeasure  388.0  BB  (1124, 323, 272, 125)
# step:  139  x_estimation  1257  y_estimation  388
# step:  140  x_objMeasure  1257.0  y_objMeasure  388.0  BB  (1124, 323, 272, 126)
# step:  140  x_estimation  1256  y_estimation  388
# step:  141  x_objMeasure  1256.0  y_objMeasure  388.0  BB  (1123, 323, 272, 126)
# step:  141  x_estimation  1256  y_estimation  387
# step:  142  x_objMeasure  1256.0  y_objMeasure  389.0  BB  (1124, 323, 271, 126)
# step:  142  x_estimation  1255  y_estimation  388
# step:  143  x_objMeasure  1257.0  y_objMeasure  389.0  BB  (1123, 324, 271, 125)
# step:  143  x_estimation  1256  y_estimation  388
# step:  144  x_objMeasure  1257.0  y_objMeasure  389.0  BB  (1123, 324, 270, 125)
# step:  144  x_estimation  1256  y_estimation  388
# step:  145  x_objMeasure  1257.0  y_objMeasure  389.0  BB  (1123, 324, 270, 126)
# step:  145  x_estimation  1256  y_estimation  388
# step:  146  x_objMeasure  1257.0  y_objMeasure  390.0  BB  (1123, 324, 270, 126)
# step:  146  x_estimation  1256  y_estimation  389
# step:  147  x_objMeasure  1257.0  y_objMeasure  390.0  BB  (1123, 324, 270, 126)
# step:  147  x_estimation  1256  y_estimation  389
# step:  148  x_objMeasure  1257.0  y_objMeasure  390.0  BB  (1123, 324, 270, 126)
# step:  148  x_estimation  1256  y_estimation  389
# step:  149  x_objMeasure  1257.0  y_objMeasure  390.0  BB  (1122, 324, 271, 126)
# step:  149  x_estimation  1256  y_estimation  390
# step:  150  x_objMeasure  1257.0  y_objMeasure  390.0  BB  (1122, 324, 271, 126)
# step:  150  x_estimation  1256  y_estimation  390
# step:  151  x_objMeasure  1257.0  y_objMeasure  390.0  BB  (1122, 325, 271, 125)
# step:  151  x_estimation  1256  y_estimation  390
# step:  152  x_objMeasure  1256.0  y_objMeasure  390.0  BB  (1123, 325, 270, 125)
# step:  152  x_estimation  1257  y_estimation  390
# step:  153  x_objMeasure  1256.0  y_objMeasure  391.0  BB  (1123, 325, 270, 125)
# step:  153  x_estimation  1257  y_estimation  390
# step:  154  x_objMeasure  1256.0  y_objMeasure  391.0  BB  (1123, 325, 271, 126)
# step:  154  x_estimation  1256  y_estimation  390
# step:  155  x_objMeasure  1257.0  y_objMeasure  390.0  BB  (1123, 325, 271, 126)
# step:  155  x_estimation  1256  y_estimation  389
# step:  156  x_objMeasure  1257.0  y_objMeasure  390.0  BB  (1123, 326, 270, 125)
# step:  156  x_estimation  1256  y_estimation  389
# step:  157  x_objMeasure  1257.0  y_objMeasure  391.0  BB  (1123, 326, 270, 125)
# step:  157  x_estimation  1256  y_estimation  391
# step:  158  x_objMeasure  1257.0  y_objMeasure  391.0  BB  (1123, 326, 270, 125)
# step:  158  x_estimation  1256  y_estimation  390
# step:  159  x_objMeasure  1257.0  y_objMeasure  391.0  BB  (1123, 326, 270, 125)
# step:  159  x_estimation  1256  y_estimation  390
# step:  160  x_objMeasure  1255.0  y_objMeasure  392.0  BB  (1123, 326, 269, 125)
# step:  160  x_estimation  1256  y_estimation  391
# step:  161  x_objMeasure  1255.0  y_objMeasure  392.0  BB  (1122, 326, 270, 126)
# step:  161  x_estimation  1255  y_estimation  391
# step:  162  x_objMeasure  1254.0  y_objMeasure  392.0  BB  (1122, 326, 269, 126)
# step:  162  x_estimation  1254  y_estimation  393
# step:  163  x_objMeasure  1254.0  y_objMeasure  392.0  BB  (1122, 326, 269, 126)
# step:  163  x_estimation  1253  y_estimation  393
# step:  164  x_objMeasure  1254.0  y_objMeasure  392.0  BB  (1122, 326, 268, 126)
# step:  164  x_estimation  1253  y_estimation  392
# step:  165  x_objMeasure  1254.0  y_objMeasure  392.0  BB  (1122, 326, 268, 126)
# step:  165  x_estimation  1254  y_estimation  390
# step:  166  x_objMeasure  1254.0  y_objMeasure  392.0  BB  (1122, 326, 269, 126)
# step:  166  x_estimation  1254  y_estimation  390
# step:  167  x_objMeasure  1254.0  y_objMeasure  392.0  BB  (1122, 326, 268, 126)
# step:  167  x_estimation  1254  y_estimation  392
# step:  168  x_objMeasure  1254.0  y_objMeasure  392.0  BB  (1122, 326, 269, 126)
# step:  168  x_estimation  1254  y_estimation  392
# step:  169  x_objMeasure  1254.0  y_objMeasure  393.0  BB  (1123, 326, 268, 126)
# step:  169  x_estimation  1254  y_estimation  391
# step:  170  x_objMeasure  1254.0  y_objMeasure  392.0  BB  (1123, 326, 268, 126)
# step:  170  x_estimation  1254  y_estimation  392
# step:  171  x_objMeasure  1255.0  y_objMeasure  392.0  BB  (1123, 326, 269, 126)
# step:  171  x_estimation  1254  y_estimation  392
# step:  172  x_objMeasure  1255.0  y_objMeasure  392.0  BB  (1123, 326, 269, 126)
# step:  172  x_estimation  1255  y_estimation  392
# step:  173  x_objMeasure  1256.0  y_objMeasure  392.0  BB  (1124, 327, 269, 125)
# step:  173  x_estimation  1257  y_estimation  392
# step:  174  x_objMeasure  1256.0  y_objMeasure  392.0  BB  (1124, 327, 270, 125)
# step:  174  x_estimation  1256  y_estimation  392
# step:  175  x_objMeasure  1256.0  y_objMeasure  392.0  BB  (1124, 327, 270, 125)
# step:  175  x_estimation  1255  y_estimation  392
# step:  176  x_objMeasure  1256.0  y_objMeasure  392.0  BB  (1124, 327, 270, 125)
# step:  176  x_estimation  1255  y_estimation  392
# step:  177  x_objMeasure  1256.0  y_objMeasure  393.0  BB  (1124, 327, 269, 125)
# step:  177  x_estimation  1255  y_estimation  392
# step:  178  x_objMeasure  1256.0  y_objMeasure  393.0  BB  (1125, 327, 268, 126)
# step:  178  x_estimation  1255  y_estimation  393
# step:  179  x_objMeasure  1256.0  y_objMeasure  393.0  BB  (1125, 327, 267, 126)
# step:  179  x_estimation  1255  y_estimation  392
# step:  180  x_objMeasure  1256.0  y_objMeasure  393.0  BB  (1125, 327, 267, 126)
# step:  180  x_estimation  1256  y_estimation  393
# step:  181  x_objMeasure  1255.0  y_objMeasure  393.0  BB  (1125, 328, 266, 125)
# step:  181  x_estimation  1254  y_estimation  393
# step:  182  x_objMeasure  1255.0  y_objMeasure  393.0  BB  (1125, 328, 266, 125)
# step:  182  x_estimation  1253  y_estimation  393
# step:  183  x_objMeasure  1255.0  y_objMeasure  393.0  BB  (1125, 328, 266, 125)
# step:  183  x_estimation  1254  y_estimation  393
# step:  184  x_objMeasure  1255.0  y_objMeasure  393.0  BB  (1125, 328, 265, 125)
# step:  184  x_estimation  1254  y_estimation  393
# step:  185  x_objMeasure  1254.0  y_objMeasure  394.0  BB  (1125, 328, 264, 125)
# step:  185  x_estimation  1254  y_estimation  393
# step:  186  x_objMeasure  1254.0  y_objMeasure  394.0  BB  (1125, 328, 264, 125)
# step:  186  x_estimation  1254  y_estimation  393
# step:  187  x_objMeasure  1255.0  y_objMeasure  394.0  BB  (1125, 328, 264, 125)
# step:  187  x_estimation  1254  y_estimation  394
# step:  188  x_objMeasure  1254.0  y_objMeasure  394.0  BB  (1125, 328, 264, 126)
# step:  188  x_estimation  1255  y_estimation  395
# step:  189  x_objMeasure  1255.0  y_objMeasure  394.0  BB  (1125, 328, 264, 126)
# step:  189  x_estimation  1255  y_estimation  394
# step:  190  x_objMeasure  1255.0  y_objMeasure  394.0  BB  (1125, 328, 264, 126)
# step:  190  x_estimation  1254  y_estimation  393
# step:  191  x_objMeasure  1255.0  y_objMeasure  394.0  BB  (1125, 328, 265, 126)
# step:  191  x_estimation  1254  y_estimation  393
# step:  192  x_objMeasure  1255.0  y_objMeasure  394.0  BB  (1125, 328, 266, 126)
# step:  192  x_estimation  1255  y_estimation  394
# step:  193  x_objMeasure  1254.0  y_objMeasure  394.0  BB  (1125, 329, 268, 125)
# step:  193  x_estimation  1254  y_estimation  394
# step:  194  x_objMeasure  1254.0  y_objMeasure  394.0  BB  (1125, 329, 268, 125)
# step:  194  x_estimation  1253  y_estimation  394
# step:  195  x_objMeasure  1254.0  y_objMeasure  394.0  BB  (1125, 329, 269, 126)
# step:  195  x_estimation  1253  y_estimation  393
# step:  196  x_objMeasure  1254.0  y_objMeasure  394.0  BB  (1125, 329, 269, 126)
# step:  196  x_estimation  1253  y_estimation  394
# step:  197  x_objMeasure  1254.0  y_objMeasure  395.0  BB  (1125, 329, 268, 126)
# step:  197  x_estimation  1254  y_estimation  394
# step:  198  x_objMeasure  1253.0  y_objMeasure  395.0  BB  (1125, 329, 267, 126)
# step:  198  x_estimation  1256  y_estimation  394
# step:  199  x_objMeasure  1253.0  y_objMeasure  395.0  BB  (1125, 329, 262, 126)
# step:  199  x_estimation  1254  y_estimation  394
# step:  200  x_objMeasure  1253.0  y_objMeasure  395.0  BB  (1125, 329, 261, 126)
# step:  200  x_estimation  1252  y_estimation  394
# step:  201  x_objMeasure  1253.0  y_objMeasure  395.0  BB  (1124, 329, 261, 126)
# step:  201  x_estimation  1253  y_estimation  395
# step:  202  x_objMeasure  1252.0  y_objMeasure  396.0  BB  (1124, 330, 260, 126)
# step:  202  x_estimation  1252  y_estimation  395
# step:  203  x_objMeasure  1252.0  y_objMeasure  396.0  BB  (1124, 330, 259, 126)
# step:  203  x_estimation  1252  y_estimation  395
# step:  204  x_objMeasure  1251.0  y_objMeasure  396.0  BB  (1124, 330, 258, 126)
# step:  204  x_estimation  1250  y_estimation  395
# step:  205  x_objMeasure  1250.0  y_objMeasure  396.0  BB  (1123, 330, 258, 126)
# step:  205  x_estimation  1250  y_estimation  396
# step:  206  x_objMeasure  1250.0  y_objMeasure  396.0  BB  (1123, 330, 258, 126)
# step:  206  x_estimation  1250  y_estimation  395
# step:  207  x_objMeasure  1250.0  y_objMeasure  396.0  BB  (1123, 331, 257, 125)
# step:  207  x_estimation  1250  y_estimation  395
# step:  208  x_objMeasure  1250.0  y_objMeasure  397.0  BB  (1123, 331, 257, 125)
# step:  208  x_estimation  1250  y_estimation  396
# step:  209  x_objMeasure  1249.0  y_objMeasure  397.0  BB  (1123, 331, 257, 126)
# step:  209  x_estimation  1250  y_estimation  397
# step:  210  x_objMeasure  1249.0  y_objMeasure  397.0  BB  (1123, 331, 257, 126)
# step:  210  x_estimation  1249  y_estimation  397
# step:  211  x_objMeasure  1249.0  y_objMeasure  397.0  BB  (1123, 331, 256, 126)
# step:  211  x_estimation  1248  y_estimation  398
# step:  212  x_objMeasure  1249.0  y_objMeasure  397.0  BB  (1123, 331, 256, 126)
# step:  212  x_estimation  1248  y_estimation  397
# step:  213  x_objMeasure  1249.0  y_objMeasure  398.0  BB  (1123, 331, 256, 126)
# step:  213  x_estimation  1248  y_estimation  397
# step:  214  x_objMeasure  1249.0  y_objMeasure  398.0  BB  (1123, 332, 256, 125)
# step:  214  x_estimation  1248  y_estimation  397
# step:  215  x_objMeasure  1249.0  y_objMeasure  398.0  BB  (1123, 332, 256, 126)
# step:  215  x_estimation  1249  y_estimation  397
# step:  216  x_objMeasure  1248.0  y_objMeasure  398.0  BB  (1122, 332, 257, 126)
# step:  216  x_estimation  1248  y_estimation  397
# step:  217  x_objMeasure  1248.0  y_objMeasure  398.0  BB  (1122, 332, 257, 126)
# step:  217  x_estimation  1248  y_estimation  396
# step:  218  x_objMeasure  1248.0  y_objMeasure  399.0  BB  (1122, 332, 257, 126)
# step:  218  x_estimation  1248  y_estimation  398
# step:  219  x_objMeasure  1248.0  y_objMeasure  399.0  BB  (1122, 332, 257, 126)
# step:  219  x_estimation  1248  y_estimation  398
# step:  220  x_objMeasure  1248.0  y_objMeasure  399.0  BB  (1121, 333, 257, 125)
# step:  220  x_estimation  1247  y_estimation  399
# step:  221  x_objMeasure  1248.0  y_objMeasure  399.0  BB  (1121, 333, 256, 126)
# step:  221  x_estimation  1247  y_estimation  399
# step:  222  x_objMeasure  1248.0  y_objMeasure  399.0  BB  (1121, 333, 256, 126)
# step:  222  x_estimation  1248  y_estimation  399
# step:  223  x_objMeasure  1248.0  y_objMeasure  399.0  BB  (1121, 333, 255, 127)
# step:  223  x_estimation  1248  y_estimation  400
# step:  224  x_objMeasure  1247.0  y_objMeasure  399.0  BB  (1120, 333, 256, 126)
# step:  224  x_estimation  1247  y_estimation  400
# step:  225  x_objMeasure  1247.0  y_objMeasure  399.0  BB  (1120, 333, 256, 126)
# step:  225  x_estimation  1246  y_estimation  399
# step:  226  x_objMeasure  1246.0  y_objMeasure  400.0  BB  (1120, 333, 256, 127)
# step:  226  x_estimation  1247  y_estimation  399
# step:  227  x_objMeasure  1246.0  y_objMeasure  400.0  BB  (1120, 333, 256, 126)
# step:  227  x_estimation  1246  y_estimation  399
# step:  228  x_objMeasure  1246.0  y_objMeasure  400.0  BB  (1120, 333, 256, 127)
# step:  228  x_estimation  1245  y_estimation  400
# step:  229  x_objMeasure  1246.0  y_objMeasure  400.0  BB  (1119, 334, 257, 126)
# step:  229  x_estimation  1245  y_estimation  400
# step:  230  x_objMeasure  1246.0  y_objMeasure  401.0  BB  (1119, 334, 258, 126)
# step:  230  x_estimation  1245  y_estimation  400
# step:  231  x_objMeasure  1246.0  y_objMeasure  401.0  BB  (1119, 334, 258, 126)
# step:  231  x_estimation  1246  y_estimation  400
# step:  232  x_objMeasure  1245.0  y_objMeasure  401.0  BB  (1119, 334, 258, 126)
# step:  232  x_estimation  1245  y_estimation  399
# step:  233  x_objMeasure  1245.0  y_objMeasure  401.0  BB  (1119, 335, 257, 125)
# step:  233  x_estimation  1245  y_estimation  400
# step:  234  x_objMeasure  1244.0  y_objMeasure  401.0  BB  (1119, 335, 256, 126)
# step:  234  x_estimation  1244  y_estimation  401
# step:  235  x_objMeasure  1244.0  y_objMeasure  402.0  BB  (1119, 335, 256, 126)
# step:  235  x_estimation  1244  y_estimation  401
# step:  236  x_objMeasure  1243.0  y_objMeasure  402.0  BB  (1118, 335, 256, 126)
# step:  236  x_estimation  1243  y_estimation  401
# step:  237  x_objMeasure  1243.0  y_objMeasure  402.0  BB  (1118, 336, 255, 125)
# step:  237  x_estimation  1243  y_estimation  401
# step:  238  x_objMeasure  1243.0  y_objMeasure  402.0  BB  (1118, 336, 254, 125)
# step:  238  x_estimation  1243  y_estimation  401
# step:  239  x_objMeasure  1243.0  y_objMeasure  402.0  BB  (1118, 336, 254, 126)
# step:  239  x_estimation  1242  y_estimation  401
# step:  240  x_objMeasure  1242.0  y_objMeasure  403.0  BB  (1117, 336, 255, 126)
# step:  240  x_estimation  1243  y_estimation  402
# step:  241  x_objMeasure  1242.0  y_objMeasure  403.0  BB  (1117, 336, 255, 126)
# step:  241  x_estimation  1242  y_estimation  404
# step:  242  x_objMeasure  1241.0  y_objMeasure  403.0  BB  (1116, 336, 256, 126)
# step:  242  x_estimation  1241  y_estimation  404
# step:  243  x_objMeasure  1241.0  y_objMeasure  403.0  BB  (1116, 337, 257, 126)
# step:  243  x_estimation  1242  y_estimation  402
# step:  244  x_objMeasure  1241.0  y_objMeasure  403.0  BB  (1115, 337, 258, 126)
# step:  244  x_estimation  1240  y_estimation  403
# step:  245  x_objMeasure  1241.0  y_objMeasure  404.0  BB  (1115, 337, 258, 126)
# step:  245  x_estimation  1241  y_estimation  403
# step:  246  x_objMeasure  1241.0  y_objMeasure  404.0  BB  (1115, 337, 258, 126)
# step:  246  x_estimation  1241  y_estimation  404
# step:  247  x_objMeasure  1241.0  y_objMeasure  404.0  BB  (1115, 337, 258, 127)
# step:  247  x_estimation  1240  y_estimation  403
# step:  248  x_objMeasure  1241.0  y_objMeasure  404.0  BB  (1116, 337, 257, 127)
# step:  248  x_estimation  1240  y_estimation  402
# step:  249  x_objMeasure  1241.0  y_objMeasure  404.0  BB  (1116, 337, 258, 127)
# step:  249  x_estimation  1241  y_estimation  401
# step:  250  x_objMeasure  1241.0  y_objMeasure  404.0  BB  (1116, 338, 258, 126)
# step:  250  x_estimation  1240  y_estimation  402
# step:  251  x_objMeasure  1241.0  y_objMeasure  405.0  BB  (1116, 338, 257, 126)
# step:  251  x_estimation  1240  y_estimation  403
# step:  252  x_objMeasure  1241.0  y_objMeasure  405.0  BB  (1115, 338, 258, 126)
# step:  252  x_estimation  1240  y_estimation  404
# step:  253  x_objMeasure  1241.0  y_objMeasure  405.0  BB  (1115, 339, 258, 125)
# step:  253  x_estimation  1241  y_estimation  405
# step:  254  x_objMeasure  1240.0  y_objMeasure  405.0  BB  (1115, 339, 258, 125)
# step:  254  x_estimation  1240  y_estimation  405
# step:  255  x_objMeasure  1240.0  y_objMeasure  406.0  BB  (1115, 339, 258, 125)
# step:  255  x_estimation  1239  y_estimation  405
# step:  256  x_objMeasure  1239.0  y_objMeasure  406.0  BB  (1114, 339, 258, 126)
# step:  256  x_estimation  1239  y_estimation  404
# step:  257  x_objMeasure  1239.0  y_objMeasure  406.0  BB  (1114, 339, 257, 126)
# step:  257  x_estimation  1239  y_estimation  405
# step:  258  x_objMeasure  1238.0  y_objMeasure  406.0  BB  (1114, 339, 256, 126)
# step:  258  x_estimation  1239  y_estimation  405
# step:  259  x_objMeasure  1238.0  y_objMeasure  406.0  BB  (1113, 339, 257, 126)
# step:  259  x_estimation  1238  y_estimation  406
# step:  260  x_objMeasure  1238.0  y_objMeasure  406.0  BB  (1113, 340, 256, 125)
# step:  260  x_estimation  1238  y_estimation  408
# step:  261  x_objMeasure  1238.0  y_objMeasure  407.0  BB  (1113, 340, 256, 126)
# step:  261  x_estimation  1238  y_estimation  407
# step:  262  x_objMeasure  1238.0  y_objMeasure  407.0  BB  (1113, 340, 256, 126)
# step:  262  x_estimation  1237  y_estimation  407
# step:  263  x_objMeasure  1237.0  y_objMeasure  407.0  BB  (1113, 340, 255, 126)
# step:  263  x_estimation  1237  y_estimation  407
# step:  264  x_objMeasure  1237.0  y_objMeasure  407.0  BB  (1113, 340, 255, 126)
# step:  264  x_estimation  1237  y_estimation  407
# step:  265  x_objMeasure  1237.0  y_objMeasure  407.0  BB  (1114, 341, 254, 125)
# step:  265  x_estimation  1237  y_estimation  407
# step:  266  x_objMeasure  1237.0  y_objMeasure  407.0  BB  (1114, 341, 253, 126)
# step:  266  x_estimation  1237  y_estimation  406
# step:  267  x_objMeasure  1237.0  y_objMeasure  408.0  BB  (1114, 341, 252, 126)
# step:  267  x_estimation  1236  y_estimation  407
# step:  268  x_objMeasure  1237.0  y_objMeasure  408.0  BB  (1114, 341, 250, 127)
# step:  268  x_estimation  1238  y_estimation  408
# step:  269  x_objMeasure  1237.0  y_objMeasure  408.0  BB  (1114, 341, 250, 127)
# step:  269  x_estimation  1237  y_estimation  408
# step:  270  x_objMeasure  1237.0  y_objMeasure  408.0  BB  (1114, 341, 249, 127)
# step:  270  x_estimation  1238  y_estimation  407
# step:  271  x_objMeasure  1236.0  y_objMeasure  408.0  BB  (1114, 342, 249, 127)
# step:  271  x_estimation  1237  y_estimation  407
# step:  272  x_objMeasure  1236.0  y_objMeasure  408.0  BB  (1114, 342, 248, 127)
# step:  272  x_estimation  1236  y_estimation  407
# step:  273  x_objMeasure  1236.0  y_objMeasure  408.0  BB  (1114, 342, 247, 127)
# step:  273  x_estimation  1236  y_estimation  408
# step:  274  x_objMeasure  1235.0  y_objMeasure  409.0  BB  (1114, 343, 246, 126)
# step:  274  x_estimation  1235  y_estimation  408
# step:  275  x_objMeasure  1235.0  y_objMeasure  409.0  BB  (1114, 343, 245, 127)
# step:  275  x_estimation  1236  y_estimation  408
# step:  276  x_objMeasure  1235.0  y_objMeasure  409.0  BB  (1114, 343, 245, 127)
# step:  276  x_estimation  1235  y_estimation  409
# step:  277  x_objMeasure  1235.0  y_objMeasure  409.0  BB  (1114, 342, 244, 128)
# step:  277  x_estimation  1234  y_estimation  408
# step:  278  x_objMeasure  1234.0  y_objMeasure  409.0  BB  (1114, 343, 244, 127)
# step:  278  x_estimation  1233  y_estimation  408
# step:  279  x_objMeasure  1234.0  y_objMeasure  410.0  BB  (1114, 343, 242, 127)
# step:  279  x_estimation  1233  y_estimation  409
# step:  280  x_objMeasure  1234.0  y_objMeasure  410.0  BB  (1114, 343, 241, 128)
# step:  280  x_estimation  1234  y_estimation  409
# step:  281  x_objMeasure  1234.0  y_objMeasure  410.0  BB  (1114, 343, 241, 128)
# step:  281  x_estimation  1234  y_estimation  409
# step:  282  x_objMeasure  1234.0  y_objMeasure  410.0  BB  (1114, 343, 241, 128)
# step:  282  x_estimation  1233  y_estimation  410
# step:  283  x_objMeasure  1233.0  y_objMeasure  410.0  BB  (1114, 343, 241, 129)
# step:  283  x_estimation  1232  y_estimation  409
# step:  284  x_objMeasure  1234.0  y_objMeasure  411.0  BB  (1114, 344, 241, 128)
# step:  284  x_estimation  1233  y_estimation  409
# step:  285  x_objMeasure  1234.0  y_objMeasure  411.0  BB  (1114, 344, 242, 128)
# step:  285  x_estimation  1234  y_estimation  410
# step:  286  x_objMeasure  1234.0  y_objMeasure  411.0  BB  (1115, 345, 241, 127)
# step:  286  x_estimation  1234  y_estimation  412
# step:  287  x_objMeasure  1235.0  y_objMeasure  411.0  BB  (1115, 345, 242, 127)
# step:  287  x_estimation  1234  y_estimation  411
# step:  288  x_objMeasure  1236.0  y_objMeasure  412.0  BB  (1115, 345, 243, 128)
# step:  288  x_estimation  1235  y_estimation  411
# step:  289  x_objMeasure  1236.0  y_objMeasure  412.0  BB  (1116, 346, 243, 127)
# step:  289  x_estimation  1235  y_estimation  412
# step:  290  x_objMeasure  1236.0  y_objMeasure  412.0  BB  (1116, 346, 244, 127)
# step:  290  x_estimation  1235  y_estimation  411
# step:  291  x_objMeasure  1237.0  y_objMeasure  413.0  BB  (1116, 346, 245, 127)
# step:  291  x_estimation  1236  y_estimation  412
# step:  292  x_objMeasure  1237.0  y_objMeasure  413.0  BB  (1116, 346, 246, 128)
# step:  292  x_estimation  1236  y_estimation  412
# step:  293  x_objMeasure  1237.0  y_objMeasure  413.0  BB  (1117, 347, 246, 127)
# step:  293  x_estimation  1237  y_estimation  412
# step:  294  x_objMeasure  1237.0  y_objMeasure  413.0  BB  (1117, 347, 247, 127)
# step:  294  x_estimation  1237  y_estimation  412
# step:  295  x_objMeasure  1238.0  y_objMeasure  413.0  BB  (1117, 347, 248, 127)
# step:  295  x_estimation  1237  y_estimation  412
# step:  296  x_objMeasure  1238.0  y_objMeasure  414.0  BB  (1118, 348, 248, 126)
# step:  296  x_estimation  1237  y_estimation  413
# step:  297  x_objMeasure  1239.0  y_objMeasure  414.0  BB  (1118, 348, 249, 125)
# step:  297  x_estimation  1239  y_estimation  413
# step:  298  x_objMeasure  1239.0  y_objMeasure  415.0  BB  (1118, 349, 249, 124)
# step:  298  x_estimation  1239  y_estimation  413
# step:  299  x_objMeasure  1239.0  y_objMeasure  415.0  BB  (1118, 349, 250, 125)
# step:  299  x_estimation  1239  y_estimation  415
# step:  300  x_objMeasure  1240.0  y_objMeasure  415.0  BB  (1118, 349, 250, 125)
# step:  300  x_estimation  1240  y_estimation  414
# step:  301  x_objMeasure  1240.0  y_objMeasure  416.0  BB  (1118, 349, 251, 126)
# step:  301  x_estimation  1240  y_estimation  414
# step:  302  x_objMeasure  1240.0  y_objMeasure  416.0  BB  (1119, 350, 250, 125)
# step:  302  x_estimation  1239  y_estimation  415
# step:  303  x_objMeasure  1241.0  y_objMeasure  416.0  BB  (1118, 350, 251, 125)
# step:  303  x_estimation  1239  y_estimation  417
# step:  304  x_objMeasure  1241.0  y_objMeasure  416.0  BB  (1119, 350, 250, 126)
# step:  304  x_estimation  1240  y_estimation  416
# step:  305  x_objMeasure  1242.0  y_objMeasure  417.0  BB  (1119, 350, 250, 126)
# step:  305  x_estimation  1242  y_estimation  416
# step:  306  x_objMeasure  1243.0  y_objMeasure  417.0  BB  (1119, 351, 251, 126)
# step:  306  x_estimation  1242  y_estimation  416
# step:  307  x_objMeasure  1243.0  y_objMeasure  418.0  BB  (1119, 351, 251, 127)
# step:  307  x_estimation  1242  y_estimation  417
# step:  308  x_objMeasure  1243.0  y_objMeasure  418.0  BB  (1120, 351, 250, 127)
# step:  308  x_estimation  1242  y_estimation  418
# step:  309  x_objMeasure  1244.0  y_objMeasure  418.0  BB  (1120, 352, 251, 126)
# step:  309  x_estimation  1243  y_estimation  417
# step:  310  x_objMeasure  1244.0  y_objMeasure  419.0  BB  (1121, 352, 251, 126)
# step:  310  x_estimation  1243  y_estimation  417
# step:  311  x_objMeasure  1245.0  y_objMeasure  419.0  BB  (1121, 352, 251, 127)
# step:  311  x_estimation  1244  y_estimation  418
# step:  312  x_objMeasure  1245.0  y_objMeasure  419.0  BB  (1122, 353, 251, 126)
# step:  312  x_estimation  1244  y_estimation  418
# step:  313  x_objMeasure  1245.0  y_objMeasure  420.0  BB  (1123, 353, 250, 126)
# step:  313  x_estimation  1243  y_estimation  419
# step:  314  x_objMeasure  1246.0  y_objMeasure  420.0  BB  (1124, 353, 250, 127)
# step:  314  x_estimation  1245  y_estimation  419
# step:  315  x_objMeasure  1247.0  y_objMeasure  421.0  BB  (1124, 354, 250, 126)
# step:  315  x_estimation  1246  y_estimation  420
# step:  316  x_objMeasure  1247.0  y_objMeasure  421.0  BB  (1125, 354, 250, 126)
# step:  316  x_estimation  1246  y_estimation  420
# step:  317  x_objMeasure  1248.0  y_objMeasure  421.0  BB  (1125, 355, 250, 126)
# step:  317  x_estimation  1247  y_estimation  421
# step:  318  x_objMeasure  1248.0  y_objMeasure  421.0  BB  (1126, 355, 249, 126)
# step:  318  x_estimation  1249  y_estimation  420
# step:  319  x_objMeasure  1248.0  y_objMeasure  422.0  BB  (1126, 355, 250, 126)
# step:  319  x_estimation  1249  y_estimation  422
# step:  320  x_objMeasure  1249.0  y_objMeasure  422.0  BB  (1127, 355, 248, 126)
# step:  320  x_estimation  1249  y_estimation  422
# step:  321  x_objMeasure  1250.0  y_objMeasure  422.0  BB  (1127, 356, 249, 126)
# step:  321  x_estimation  1249  y_estimation  422
# step:  322  x_objMeasure  1250.0  y_objMeasure  423.0  BB  (1128, 356, 248, 126)
# step:  322  x_estimation  1250  y_estimation  421
# step:  323  x_objMeasure  1250.0  y_objMeasure  423.0  BB  (1129, 356, 246, 126)
# step:  323  x_estimation  1250  y_estimation  423
# step:  324  x_objMeasure  1250.0  y_objMeasure  423.0  BB  (1129, 357, 246, 125)
# step:  324  x_estimation  1250  y_estimation  424
# step:  325  x_objMeasure  1250.0  y_objMeasure  424.0  BB  (1130, 356, 244, 127)
# step:  325  x_estimation  1249  y_estimation  424
# step:  326  x_objMeasure  1250.0  y_objMeasure  424.0  BB  (1130, 357, 244, 126)
# step:  326  x_estimation  1249  y_estimation  424
# step:  327  x_objMeasure  1251.0  y_objMeasure  424.0  BB  (1131, 357, 243, 127)
# step:  327  x_estimation  1250  y_estimation  424
# step:  328  x_objMeasure  1252.0  y_objMeasure  425.0  BB  (1132, 357, 243, 128)
# step:  328  x_estimation  1250  y_estimation  425
# step:  329  x_objMeasure  1252.0  y_objMeasure  425.0  BB  (1132, 358, 244, 128)
# step:  329  x_estimation  1251  y_estimation  425
# step:  330  x_objMeasure  1253.0  y_objMeasure  425.0  BB  (1133, 358, 243, 128)
# step:  330  x_estimation  1251  y_estimation  424
# step:  331  x_objMeasure  1253.0  y_objMeasure  425.0  BB  (1133, 359, 243, 128)
# step:  331  x_estimation  1251  y_estimation  424
# step:  332  x_objMeasure  1254.0  y_objMeasure  426.0  BB  (1134, 359, 242, 128)
# step:  332  x_estimation  1252  y_estimation  424
# step:  333  x_objMeasure  1255.0  y_objMeasure  426.0  BB  (1134, 359, 243, 129)
# step:  333  x_estimation  1254  y_estimation  425
# step:  334  x_objMeasure  1255.0  y_objMeasure  426.0  BB  (1135, 359, 242, 129)
# step:  334  x_estimation  1255  y_estimation  426
# step:  335  x_objMeasure  1256.0  y_objMeasure  427.0  BB  (1135, 360, 242, 128)
# step:  335  x_estimation  1256  y_estimation  426
# step:  336  x_objMeasure  1256.0  y_objMeasure  427.0  BB  (1136, 361, 242, 127)
# step:  336  x_estimation  1256  y_estimation  425
# step:  337  x_objMeasure  1257.0  y_objMeasure  428.0  BB  (1137, 361, 241, 128)
# step:  337  x_estimation  1257  y_estimation  427
# step:  338  x_objMeasure  1257.0  y_objMeasure  428.0  BB  (1137, 361, 241, 128)
# step:  338  x_estimation  1257  y_estimation  428
# step:  339  x_objMeasure  1258.0  y_objMeasure  429.0  BB  (1138, 362, 240, 128)
# step:  339  x_estimation  1257  y_estimation  428
# step:  340  x_objMeasure  1258.0  y_objMeasure  429.0  BB  (1138, 362, 241, 128)
# step:  340  x_estimation  1257  y_estimation  428
# step:  341  x_objMeasure  1259.0  y_objMeasure  430.0  BB  (1139, 362, 240, 128)
# step:  341  x_estimation  1258  y_estimation  429
# step:  342  x_objMeasure  1260.0  y_objMeasure  430.0  BB  (1140, 363, 239, 128)
# step:  342  x_estimation  1259  y_estimation  431
# step:  343  x_objMeasure  1260.0  y_objMeasure  430.0  BB  (1140, 363, 239, 128)
# step:  343  x_estimation  1259  y_estimation  430
# step:  344  x_objMeasure  1261.0  y_objMeasure  431.0  BB  (1141, 364, 238, 128)
# step:  344  x_estimation  1259  y_estimation  430
# step:  345  x_objMeasure  1261.0  y_objMeasure  431.0  BB  (1142, 363, 238, 129)
# step:  345  x_estimation  1260  y_estimation  431
# step:  346  x_objMeasure  1263.0  y_objMeasure  431.0  BB  (1143, 364, 238, 128)
# step:  346  x_estimation  1261  y_estimation  430
# step:  347  x_objMeasure  1263.0  y_objMeasure  432.0  BB  (1143, 364, 238, 129)
# step:  347  x_estimation  1262  y_estimation  431
# step:  348  x_objMeasure  1263.0  y_objMeasure  432.0  BB  (1144, 365, 238, 128)
# step:  348  x_estimation  1262  y_estimation  431
# step:  349  x_objMeasure  1264.0  y_objMeasure  432.0  BB  (1145, 365, 238, 128)
# step:  349  x_estimation  1263  y_estimation  432
# step:  350  x_objMeasure  1265.0  y_objMeasure  433.0  BB  (1145, 365, 239, 129)
# step:  350  x_estimation  1264  y_estimation  432
# step:  351  x_objMeasure  1265.0  y_objMeasure  433.0  BB  (1146, 366, 239, 128)
# step:  351  x_estimation  1265  y_estimation  432
# step:  352  x_objMeasure  1266.0  y_objMeasure  434.0  BB  (1147, 367, 240, 128)
# step:  352  x_estimation  1265  y_estimation  432
# step:  353  x_objMeasure  1267.0  y_objMeasure  434.0  BB  (1147, 367, 241, 128)
# step:  353  x_estimation  1266  y_estimation  433
# step:  354  x_objMeasure  1268.0  y_objMeasure  434.0  BB  (1148, 367, 241, 128)
# step:  354  x_estimation  1267  y_estimation  433
# step:  355  x_objMeasure  1269.0  y_objMeasure  434.0  BB  (1149, 367, 241, 128)
# step:  355  x_estimation  1268  y_estimation  433
# step:  356  x_objMeasure  1269.0  y_objMeasure  435.0  BB  (1149, 367, 242, 129)
# step:  356  x_estimation  1268  y_estimation  434
# step:  357  x_objMeasure  1270.0  y_objMeasure  435.0  BB  (1150, 368, 242, 128)
# step:  357  x_estimation  1269  y_estimation  434
# step:  358  x_objMeasure  1271.0  y_objMeasure  435.0  BB  (1151, 368, 242, 128)
# step:  358  x_estimation  1269  y_estimation  435
# step:  359  x_objMeasure  1272.0  y_objMeasure  436.0  BB  (1152, 369, 241, 128)
# step:  359  x_estimation  1270  y_estimation  436
# step:  360  x_objMeasure  1273.0  y_objMeasure  437.0  BB  (1152, 369, 242, 128)
# step:  360  x_estimation  1272  y_estimation  436
# step:  361  x_objMeasure  1274.0  y_objMeasure  437.0  BB  (1153, 369, 241, 129)
# step:  361  x_estimation  1272  y_estimation  436
# step:  362  x_objMeasure  1275.0  y_objMeasure  437.0  BB  (1154, 369, 241, 129)
# step:  362  x_estimation  1274  y_estimation  438
# step:  363  x_objMeasure  1275.0  y_objMeasure  438.0  BB  (1155, 370, 240, 129)
# step:  363  x_estimation  1274  y_estimation  438
# step:  364  x_objMeasure  1276.0  y_objMeasure  438.0  BB  (1155, 370, 241, 129)
# step:  364  x_estimation  1275  y_estimation  437
# step:  365  x_objMeasure  1277.0  y_objMeasure  438.0  BB  (1156, 370, 241, 129)
# step:  365  x_estimation  1276  y_estimation  437
# step:  366  x_objMeasure  1278.0  y_objMeasure  439.0  BB  (1157, 370, 241, 129)
# step:  366  x_estimation  1276  y_estimation  438
# step:  367  x_objMeasure  1279.0  y_objMeasure  439.0  BB  (1157, 371, 242, 129)
# step:  367  x_estimation  1278  y_estimation  438
# step:  368  x_objMeasure  1280.0  y_objMeasure  439.0  BB  (1158, 371, 243, 129)
# step:  368  x_estimation  1279  y_estimation  439
# ...
# step:  867  x_estimation  1442  y_estimation  400
# step:  868  x_objMeasure  1442.0  y_objMeasure  400.0  BB_t  (1312.0, 340.0, 260.0, 120.0)
# step:  868  x_estimation  1442  y_estimation  399
# step:  869  x_objMeasure  1442.0  y_objMeasure  400.0  BB_t  (1312.0, 340.0, 260.0, 120.0)
# step:  869  x_estimation  1442  y_estimation  399
# step:  870  x_objMeasure  1442.0  y_objMeasure  400.0  BB_t  (1312.0, 340.0, 260.0, 120.0)
# step:  870  x_estimation  1442  y_estimation  399
# step:  871  x_objMeasure  1442.0  y_objMeasure  400.0  BB_t  (1312.0, 340.0, 260.0, 120.0)
# step:  871  x_estimation  1441  y_estimation  400
# step:  872  x_objMeasure  1442.0  y_objMeasure  400.0  BB_t  (1312.0, 340.0, 260.0, 120.0)
# step:  872  x_estimation  1442  y_estimation  400
# step:  873  x_objMeasure  1442.0  y_objMeasure  400.0  BB_t  (1312.0, 340.0, 260.0, 120.0)
# step:  873  x_estimation  1441  y_estimation  399
# step:  874  x_objMeasure  1442.0  y_objMeasure  400.0  BB_t  (1312.0, 340.0, 260.0, 120.0)
# step:  874  x_estimation  1441  y_estimation  398
# step:  875  x_objMeasure  1440.0  y_objMeasure  400.0  BB_t  (1310.0, 340.0, 260.0, 120.0)
# step:  875  x_estimation  1440  y_estimation  399
# step:  876  x_objMeasure  1440.0  y_objMeasure  400.0  BB_t  (1310.0, 340.0, 260.0, 120.0)
# step:  876  x_estimation  1439  y_estimation  398
# step:  877  x_objMeasure  1440.0  y_objMeasure  400.0  BB_t  (1310.0, 340.0, 260.0, 120.0)
# step:  877  x_estimation  1440  y_estimation  400
# step:  878  x_objMeasure  1440.0  y_objMeasure  400.0  BB_t  (1310.0, 340.0, 260.0, 120.0)
# step:  878  x_estimation  1439  y_estimation  400
# step:  879  x_objMeasure  1438.0  y_objMeasure  400.0  BB_t  (1308.0, 340.0, 260.0, 120.0)
# step:  879  x_estimation  1438  y_estimation  399
# step:  880  x_objMeasure  1438.0  y_objMeasure  400.0  BB_t  (1308.0, 340.0, 260.0, 120.0)
# step:  880  x_estimation  1438  y_estimation  399
# step:  881  x_objMeasure  1438.0  y_objMeasure  400.0  BB_t  (1308.0, 340.0, 260.0, 120.0)
# step:  881  x_estimation  1438  y_estimation  399
# step:  882  x_objMeasure  1438.0  y_objMeasure  400.0  BB_t  (1308.0, 340.0, 260.0, 120.0)
# step:  882  x_estimation  1438  y_estimation  399
# step:  883  x_objMeasure  1438.0  y_objMeasure  400.0  BB_t  (1308.0, 340.0, 260.0, 120.0)
# step:  883  x_estimation  1438  y_estimation  399
# step:  884  x_objMeasure  1436.0  y_objMeasure  400.0  BB_t  (1306.0, 340.0, 260.0, 120.0)
# step:  884  x_estimation  1436  y_estimation  399
# step:  885  x_objMeasure  1436.0  y_objMeasure  400.0  BB_t  (1306.0, 340.0, 260.0, 120.0)
# step:  885  x_estimation  1435  y_estimation  399
# step:  886  x_objMeasure  1436.0  y_objMeasure  400.0  BB_t  (1306.0, 340.0, 260.0, 120.0)
# step:  886  x_estimation  1435  y_estimation  399
# step:  887  x_objMeasure  1436.0  y_objMeasure  400.0  BB_t  (1306.0, 340.0, 260.0, 120.0)
# step:  887  x_estimation  1435  y_estimation  400
# step:  888  x_objMeasure  1436.0  y_objMeasure  400.0  BB_t  (1306.0, 340.0, 260.0, 120.0)
# step:  888  x_estimation  1435  y_estimation  399
# step:  889  x_objMeasure  1436.0  y_objMeasure  400.0  BB_t  (1306.0, 340.0, 260.0, 120.0)
# step:  889  x_estimation  1435  y_estimation  399
# step:  890  x_objMeasure  1436.0  y_objMeasure  400.0  BB_t  (1306.0, 340.0, 260.0, 120.0)
# step:  890  x_estimation  1435  y_estimation  400
# step:  891  x_objMeasure  1436.0  y_objMeasure  400.0  BB_t  (1306.0, 340.0, 260.0, 120.0)
# step:  891  x_estimation  1435  y_estimation  400
# step:  892  x_objMeasure  1436.0  y_objMeasure  400.0  BB_t  (1306.0, 340.0, 260.0, 120.0)
# step:  892  x_estimation  1435  y_estimation  400
# step:  893  x_objMeasure  1434.0  y_objMeasure  398.0  BB_t  (1304.0, 338.0, 260.0, 120.0)
# step:  893  x_estimation  1434  y_estimation  398
# step:  894  x_objMeasure  1434.0  y_objMeasure  398.0  BB_t  (1304.0, 338.0, 260.0, 120.0)
# step:  894  x_estimation  1434  y_estimation  397
# step:  895  x_objMeasure  1434.0  y_objMeasure  398.0  BB_t  (1304.0, 338.0, 260.0, 120.0)
# step:  895  x_estimation  1433  y_estimation  397
# step:  896  x_objMeasure  1434.0  y_objMeasure  398.0  BB_t  (1304.0, 338.0, 260.0, 120.0)
# step:  896  x_estimation  1433  y_estimation  397
# step:  897  x_objMeasure  1434.0  y_objMeasure  398.0  BB_t  (1304.0, 338.0, 260.0, 120.0)
# step:  897  x_estimation  1434  y_estimation  397
# step:  898  x_objMeasure  1434.0  y_objMeasure  398.0  BB_t  (1304.0, 338.0, 260.0, 120.0)
# step:  898  x_estimation  1434  y_estimation  398
# step:  899  x_objMeasure  1432.0  y_objMeasure  398.0  BB_t  (1302.0, 338.0, 260.0, 120.0)
# step:  899  x_estimation  1433  y_estimation  398
# step:  900  x_objMeasure  1432.0  y_objMeasure  398.0  BB_t  (1302.0, 338.0, 260.0, 120.0)
# step:  900  x_estimation  1432  y_estimation  398
# step:  901  x_objMeasure  1432.0  y_objMeasure  398.0  BB_t  (1302.0, 338.0, 260.0, 120.0)
# step:  901  x_estimation  1432  y_estimation  398
# step:  902  x_objMeasure  1432.0  y_objMeasure  398.0  BB_t  (1302.0, 338.0, 260.0, 120.0)
# step:  902  x_estimation  1431  y_estimation  398
# step:  903  x_objMeasure  1432.0  y_objMeasure  398.0  BB_t  (1302.0, 338.0, 260.0, 120.0)
# step:  903  x_estimation  1431  y_estimation  398
# step:  904  x_objMeasure  1430.0  y_objMeasure  398.0  BB_t  (1300.0, 338.0, 260.0, 120.0)
# step:  904  x_estimation  1430  y_estimation  398
# step:  905  x_objMeasure  1430.0  y_objMeasure  398.0  BB_t  (1300.0, 338.0, 260.0, 120.0)
# step:  905  x_estimation  1429  y_estimation  397
# step:  906  x_objMeasure  1430.0  y_objMeasure  398.0  BB_t  (1300.0, 338.0, 260.0, 120.0)
# step:  906  x_estimation  1429  y_estimation  398
# step:  907  x_objMeasure  1428.0  y_objMeasure  398.0  BB_t  (1298.0, 338.0, 260.0, 120.0)
# step:  907  x_estimation  1429  y_estimation  398
# step:  908  x_objMeasure  1428.0  y_objMeasure  398.0  BB_t  (1298.0, 338.0, 260.0, 120.0)
# step:  908  x_estimation  1428  y_estimation  398
# step:  909  x_objMeasure  1428.0  y_objMeasure  398.0  BB_t  (1298.0, 338.0, 260.0, 120.0)
# step:  909  x_estimation  1427  y_estimation  399
# step:  910  x_objMeasure  1426.0  y_objMeasure  398.0  BB_t  (1296.0, 338.0, 260.0, 120.0)
# step:  910  x_estimation  1426  y_estimation  398
# step:  911  x_objMeasure  1426.0  y_objMeasure  398.0  BB_t  (1296.0, 338.0, 260.0, 120.0)
# step:  911  x_estimation  1425  y_estimation  398
# step:  912  x_objMeasure  1426.0  y_objMeasure  398.0  BB_t  (1296.0, 338.0, 260.0, 120.0)
# step:  912  x_estimation  1425  y_estimation  397
# step:  913  x_objMeasure  1426.0  y_objMeasure  398.0  BB_t  (1296.0, 338.0, 260.0, 120.0)
# step:  913  x_estimation  1425  y_estimation  396
# step:  914  x_objMeasure  1426.0  y_objMeasure  398.0  BB_t  (1296.0, 338.0, 260.0, 120.0)
# step:  914  x_estimation  1425  y_estimation  397
# step:  915  x_objMeasure  1426.0  y_objMeasure  398.0  BB_t  (1296.0, 338.0, 260.0, 120.0)
# step:  915  x_estimation  1425  y_estimation  397
# step:  916  x_objMeasure  1426.0  y_objMeasure  398.0  BB_t  (1296.0, 338.0, 260.0, 120.0)
# step:  916  x_estimation  1426  y_estimation  397
# step:  917  x_objMeasure  1424.0  y_objMeasure  398.0  BB_t  (1294.0, 338.0, 260.0, 120.0)
# step:  917  x_estimation  1425  y_estimation  397
# step:  918  x_objMeasure  1424.0  y_objMeasure  398.0  BB_t  (1294.0, 338.0, 260.0, 120.0)
# step:  918  x_estimation  1424  y_estimation  397
# step:  919  x_objMeasure  1424.0  y_objMeasure  398.0  BB_t  (1294.0, 338.0, 260.0, 120.0)
# step:  919  x_estimation  1424  y_estimation  398
# step:  920  x_objMeasure  1424.0  y_objMeasure  398.0  BB_t  (1294.0, 338.0, 260.0, 120.0)
# step:  920  x_estimation  1424  y_estimation  397
# step:  921  x_objMeasure  1424.0  y_objMeasure  398.0  BB_t  (1294.0, 338.0, 260.0, 120.0)
# step:  921  x_estimation  1424  y_estimation  398
# step:  922  x_objMeasure  1422.0  y_objMeasure  398.0  BB_t  (1292.0, 338.0, 260.0, 120.0)
# step:  922  x_estimation  1423  y_estimation  398
# step:  923  x_objMeasure  1422.0  y_objMeasure  398.0  BB_t  (1292.0, 338.0, 260.0, 120.0)
# step:  923  x_estimation  1422  y_estimation  398
# step:  924  x_objMeasure  1422.0  y_objMeasure  398.0  BB_t  (1292.0, 338.0, 260.0, 120.0)
# step:  924  x_estimation  1421  y_estimation  398
# step:  925  x_objMeasure  1420.0  y_objMeasure  398.0  BB_t  (1290.0, 338.0, 260.0, 120.0)
# step:  925  x_estimation  1420  y_estimation  398
# step:  926  x_objMeasure  1420.0  y_objMeasure  398.0  BB_t  (1290.0, 338.0, 260.0, 120.0)
# step:  926  x_estimation  1419  y_estimation  397
# step:  927  x_objMeasure  1420.0  y_objMeasure  398.0  BB_t  (1290.0, 338.0, 260.0, 120.0)
# step:  927  x_estimation  1420  y_estimation  397
# step:  928  x_objMeasure  1418.0  y_objMeasure  398.0  BB_t  (1288.0, 338.0, 260.0, 120.0)
# step:  928  x_estimation  1419  y_estimation  398
# step:  929  x_objMeasure  1418.0  y_objMeasure  398.0  BB_t  (1288.0, 338.0, 260.0, 120.0)
# step:  929  x_estimation  1419  y_estimation  398
# step:  930  x_objMeasure  1418.0  y_objMeasure  398.0  BB_t  (1288.0, 338.0, 260.0, 120.0)
# step:  930  x_estimation  1417  y_estimation  397
# step:  931  x_objMeasure  1418.0  y_objMeasure  398.0  BB_t  (1288.0, 338.0, 260.0, 120.0)
# step:  931  x_estimation  1418  y_estimation  397
# step:  932  x_objMeasure  1416.0  y_objMeasure  398.0  BB_t  (1286.0, 338.0, 260.0, 120.0)
# step:  932  x_estimation  1417  y_estimation  397
# step:  933  x_objMeasure  1416.0  y_objMeasure  398.0  BB_t  (1286.0, 338.0, 260.0, 120.0)
# step:  933  x_estimation  1416  y_estimation  398
# step:  934  x_objMeasure  1416.0  y_objMeasure  398.0  BB_t  (1286.0, 338.0, 260.0, 120.0)
# step:  934  x_estimation  1416  y_estimation  398
# step:  935  x_objMeasure  1416.0  y_objMeasure  398.0  BB_t  (1286.0, 338.0, 260.0, 120.0)
# step:  935  x_estimation  1416  y_estimation  398
# step:  936  x_objMeasure  1414.0  y_objMeasure  398.0  BB_t  (1284.0, 338.0, 260.0, 120.0)
# step:  936  x_estimation  1415  y_estimation  398
# step:  937  x_objMeasure  1414.0  y_objMeasure  398.0  BB_t  (1284.0, 338.0, 260.0, 120.0)
# step:  937  x_estimation  1414  y_estimation  397
# step:  938  x_objMeasure  1414.0  y_objMeasure  398.0  BB_t  (1284.0, 338.0, 260.0, 120.0)
# step:  938  x_estimation  1413  y_estimation  396
# step:  939  x_objMeasure  1414.0  y_objMeasure  398.0  BB_t  (1284.0, 338.0, 260.0, 120.0)
# step:  939  x_estimation  1414  y_estimation  396
# step:  940  x_objMeasure  1414.0  y_objMeasure  398.0  BB_t  (1284.0, 338.0, 260.0, 120.0)
# step:  940  x_estimation  1413  y_estimation  396
# step:  941  x_objMeasure  1412.0  y_objMeasure  398.0  BB_t  (1282.0, 338.0, 260.0, 120.0)
# step:  941  x_estimation  1413  y_estimation  397
# step:  942  x_objMeasure  1412.0  y_objMeasure  398.0  BB_t  (1282.0, 338.0, 260.0, 120.0)
# step:  942  x_estimation  1413  y_estimation  397
# step:  943  x_objMeasure  1412.0  y_objMeasure  398.0  BB_t  (1282.0, 338.0, 260.0, 120.0)
# step:  943  x_estimation  1413  y_estimation  397
# step:  944  x_objMeasure  1412.0  y_objMeasure  398.0  BB_t  (1282.0, 338.0, 260.0, 120.0)
# step:  944  x_estimation  1412  y_estimation  397
# step:  945  x_objMeasure  1412.0  y_objMeasure  398.0  BB_t  (1282.0, 338.0, 260.0, 120.0)
# step:  945  x_estimation  1411  y_estimation  398
# step:  946  x_objMeasure  1412.0  y_objMeasure  398.0  BB_t  (1282.0, 338.0, 260.0, 120.0)
# step:  946  x_estimation  1412  y_estimation  398
# step:  947  x_objMeasure  1410.0  y_objMeasure  398.0  BB_t  (1280.0, 338.0, 260.0, 120.0)
# step:  947  x_estimation  1410  y_estimation  398
# step:  948  x_objMeasure  1410.0  y_objMeasure  398.0  BB_t  (1280.0, 338.0, 260.0, 120.0)
# step:  948  x_estimation  1409  y_estimation  398
# step:  949  x_objMeasure  1410.0  y_objMeasure  398.0  BB_t  (1280.0, 338.0, 260.0, 120.0)
# step:  949  x_estimation  1409  y_estimation  398
# step:  950  x_objMeasure  1410.0  y_objMeasure  398.0  BB_t  (1280.0, 338.0, 260.0, 120.0)
# step:  950  x_estimation  1410  y_estimation  397
# step:  951  x_objMeasure  1408.0  y_objMeasure  398.0  BB_t  (1278.0, 338.0, 260.0, 120.0)
# step:  951  x_estimation  1409  y_estimation  397
# step:  952  x_objMeasure  1408.0  y_objMeasure  398.0  BB_t  (1278.0, 338.0, 260.0, 120.0)
# step:  952  x_estimation  1408  y_estimation  397
# step:  953  x_objMeasure  1408.0  y_objMeasure  398.0  BB_t  (1278.0, 338.0, 260.0, 120.0)
# step:  953  x_estimation  1408  y_estimation  397
# step:  954  x_objMeasure  1406.0  y_objMeasure  398.0  BB_t  (1276.0, 338.0, 260.0, 120.0)
# step:  954  x_estimation  1407  y_estimation  397
# step:  955  x_objMeasure  1406.0  y_objMeasure  398.0  BB_t  (1276.0, 338.0, 260.0, 120.0)
# step:  955  x_estimation  1405  y_estimation  396
# step:  956  x_objMeasure  1406.0  y_objMeasure  398.0  BB_t  (1276.0, 338.0, 260.0, 120.0)
# step:  956  x_estimation  1406  y_estimation  397
# step:  957  x_objMeasure  1406.0  y_objMeasure  398.0  BB_t  (1276.0, 338.0, 260.0, 120.0)
# step:  957  x_estimation  1406  y_estimation  397
# step:  958  x_objMeasure  1404.0  y_objMeasure  398.0  BB_t  (1274.0, 338.0, 260.0, 120.0)
# step:  958  x_estimation  1405  y_estimation  398
# step:  959  x_objMeasure  1404.0  y_objMeasure  398.0  BB_t  (1274.0, 338.0, 260.0, 120.0)
# step:  959  x_estimation  1405  y_estimation  398
# step:  960  x_objMeasure  1404.0  y_objMeasure  398.0  BB_t  (1274.0, 338.0, 260.0, 120.0)
# step:  960  x_estimation  1404  y_estimation  398
# step:  961  x_objMeasure  1404.0  y_objMeasure  398.0  BB_t  (1274.0, 338.0, 260.0, 120.0)
# step:  961  x_estimation  1403  y_estimation  397
# step:  962  x_objMeasure  1404.0  y_objMeasure  398.0  BB_t  (1274.0, 338.0, 260.0, 120.0)
# step:  962  x_estimation  1403  y_estimation  397
# step:  963  x_objMeasure  1404.0  y_objMeasure  398.0  BB_t  (1274.0, 338.0, 260.0, 120.0)
# step:  963  x_estimation  1404  y_estimation  397
# step:  964  x_objMeasure  1404.0  y_objMeasure  398.0  BB_t  (1274.0, 338.0, 260.0, 120.0)
# step:  964  x_estimation  1403  y_estimation  397
# step:  965  x_objMeasure  1404.0  y_objMeasure  398.0  BB_t  (1274.0, 338.0, 260.0, 120.0)
# step:  965  x_estimation  1403  y_estimation  398
# step:  966  x_objMeasure  1404.0  y_objMeasure  398.0  BB_t  (1274.0, 338.0, 260.0, 120.0)
# step:  966  x_estimation  1404  y_estimation  397
# step:  967  x_objMeasure  1404.0  y_objMeasure  398.0  BB_t  (1274.0, 338.0, 260.0, 120.0)
# step:  967  x_estimation  1404  y_estimation  397
# step:  968  x_objMeasure  1404.0  y_objMeasure  398.0  BB_t  (1274.0, 338.0, 260.0, 120.0)
# step:  968  x_estimation  1404  y_estimation  397
# step:  969  x_objMeasure  1402.0  y_objMeasure  398.0  BB_t  (1272.0, 338.0, 260.0, 120.0)
# step:  969  x_estimation  1403  y_estimation  398
# step:  970  x_objMeasure  1402.0  y_objMeasure  398.0  BB_t  (1272.0, 338.0, 260.0, 120.0)
# step:  970  x_estimation  1403  y_estimation  398
# step:  971  x_objMeasure  1402.0  y_objMeasure  398.0  BB_t  (1272.0, 338.0, 260.0, 120.0)
# step:  971  x_estimation  1402  y_estimation  397
# step:  972  x_objMeasure  1402.0  y_objMeasure  398.0  BB_t  (1272.0, 338.0, 260.0, 120.0)
# step:  972  x_estimation  1401  y_estimation  397
# step:  973  x_objMeasure  1402.0  y_objMeasure  398.0  BB_t  (1272.0, 338.0, 260.0, 120.0)
# step:  973  x_estimation  1402  y_estimation  398
# step:  974  x_objMeasure  1400.0  y_objMeasure  398.0  BB_t  (1270.0, 338.0, 260.0, 120.0)
# step:  974  x_estimation  1401  y_estimation  398
# step:  975  x_objMeasure  1400.0  y_objMeasure  398.0  BB_t  (1270.0, 338.0, 260.0, 120.0)
# step:  975  x_estimation  1400  y_estimation  398
# step:  976  x_objMeasure  1400.0  y_objMeasure  398.0  BB_t  (1270.0, 338.0, 260.0, 120.0)
# step:  976  x_estimation  1400  y_estimation  397
# step:  977  x_objMeasure  1398.0  y_objMeasure  398.0  BB_t  (1268.0, 338.0, 260.0, 120.0)
# step:  977  x_estimation  1399  y_estimation  398
# step:  978  x_objMeasure  1398.0  y_objMeasure  398.0  BB_t  (1268.0, 338.0, 260.0, 120.0)
# step:  978  x_estimation  1397  y_estimation  397
# step:  979  x_objMeasure  1398.0  y_objMeasure  398.0  BB_t  (1268.0, 338.0, 260.0, 120.0)
# step:  979  x_estimation  1398  y_estimation  398
# step:  980  x_objMeasure  1396.0  y_objMeasure  398.0  BB_t  (1266.0, 338.0, 260.0, 120.0)
# step:  980  x_estimation  1397  y_estimation  398

# %%
prog_duration= time.time() - start_time
prog_duration
# Out:
# 72.86523127555847

# %%
prog_duration/60
# Out:
# 1.2144205212593078

# %%
prog_duration/(60*Tot)
# Out:
# 1.2144205212593078

# %%
sum(n_resampl_l)/Tot
# Out:
# 406.0

# %%
len(BB_l),len(xy_est_l),len(BB_avg),len(xy_est_avg)
# Out:
# (980, 980, 1, 1)

# %%
len(BB_l),len(xy_est_l),len(BB_avg),len(xy_est_avg),len(particles_avg),len(ssim_avg),\
len(anchor_avg)
# Out:
# (980, 980, 1, 1, 1, 1, 1)

# %%
sum(cis_l)/Tot,sum(track_call_l)/Tot,sum(track_ctr_l)/Tot
# Out:
# (739.0, 241.0, 241.0)

# %%
BB_l_avg=[] 
BB_avg=np.array(BB_avg)
BB_l_avg=np.sum(BB_avg,0)/Tot

# %%
xy_est_l_avg=[] 
xy_est_avg=np.array(xy_est_avg)
xy_est_l_avg=np.sum(xy_est_avg,0)/Tot
xy_est_l_avg
# Out:
# array([[1117.,  468.],
#        [1228.,  393.],
#        [1273.,  350.],
#        ...,
#        [1397.,  397.],
#        [1398.,  398.],
#        [1397.,  398.]])

# %%
ssim_l_avg=[] 
ssim_avg=np.array(ssim_avg)
ssim_l_avg=np.sum(ssim_avg,0)/Tot

# %%
particles_l_avg=[] 
particles_avg=np.array(particles_avg)
particles_l_avg=np.sum(particles_avg,0)/Tot

# %%
anchor_l_avg=[] 
anchor_avg=np.array(anchor_avg)
anchor_l_avg=np.sum(anchor_avg,0)/Tot
anchor_l_avg
# Out:
# array([[1250.,  350.],
#        [1250.,  364.],
#        [1252.,  364.],
#        ...,
#        [1399.,  398.],
#        [1397.,  397.],
#        [1398.,  398.]])

# %%
#xy_est_l

# %%
#BB_l

# %%
np.save(path+'xy_data2_'+tracker+'.npy',np.array(xy_est_l_avg))
np.save(path+'BB_data2_'+tracker+'.npy',np.array(BB_l_avg))
np.save(path+'ssim_data2_'+tracker+'.npy',np.array(ssim_l_avg))
np.save(path+'part_data2_'+tracker+'.npy',np.array(particles_l_avg))
np.save(path+'anchor_data2_'+tracker+'.npy',np.array(anchor_l_avg))
