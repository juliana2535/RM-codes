# %%
#The MIT License (MIT)

#Copyright (c) 2020 Juliana T.C. Marcos

#THE SOFTWARE IS PROVIDED "AS IS", WITHOUT WARRANTY OF ANY KIND, EXPRESS OR IMPLIED, INCLUDING BUT NOT LIMITED TO
#THE WARRANTIES OF MERCHANTABILITY, FITNESS FOR A PARTICULAR PURPOSE AND NONINFRINGEMENT. IN NO EVENT SHALL THE 
#AUTHORS OR COPYRIGHT HOLDERS BE LIABLE FOR ANY CLAIM, DAMAGES OR OTHER LIABILITY, WHETHER IN AN ACTION OF 
#CONTRACT, TORT OR OTHERWISE, ARISING FROM, OUT OF OR IN CONNECTION WITH THE SOFTWARE OR THE USE OR OTHER DEALINGS IN THE SOFTWARE.

#This code use methods of the ParticleFilter (PF) class in order to track an object in a video. The PF uses as
#measurements provider the You Only Look Once (YOLO) object detector. 

#The particles are represented in red, the PF estimate of
#the tracked animal is represented in green and the animal's bb is represented in blue. 

#Thanks to Nayak for the nice tutorial about using YOLOv3 with OpenCv which is available at this address:
#https://www.learnopencv.com/deep-learning-based-object-detection-using-yolov3-with-opencv-python-c/

# %%
#Import of useful librairies
import cv2
import math
import numpy as np
from skimage import measure
from ParticleFilter import ParticleFilter
import time

# %%
"""Some variables initialization """

#The total number of trials
Tot=1
#Lists for the Tot running outputs averages 
BB_avg=[]
ROI_avg=[]
anchor_avg=[]
xy_est_avg=[]
particles_avg=[]
#number of particles
n_particles=2000
#noise in sensors' measurements
meas_noise=0
#Read weights and config files to create YOLO(v3) net
net = cv2.dnn.readNet("./Inputs/yolov3.weights", "./Inputs/yolov3.cfg")
#Fetch the three output layers names of YOLO net, they are the ones not connected to 
#any following layers since they are the last layers
layer_names = net.getLayerNames()
output_layer_names = [layer_names[i[0] - 1] for i in net.getUnconnectedOutLayers()]
#Read the classes in coco.names file for YOLO net
coco_classes = []
with open ('./Inputs/coco.names','r') as file:
    coco_classes=[line.strip("\n") for line in file.readlines()]

font = cv2.FONT_HERSHEY_SIMPLEX
text_coord=(10,40)
t_size=0.8
t_thick=2
#This value was chosen according to a paper experiment
N_thresh=(2*n_particles)/30
#Scale for YOLO's inputs preprocessing
scale=1/255
#Video frame width and height
frame_width=1920
frame_height=1080
#Lists to contain the counters for each trial
yolo_det_l=[]
n_resampl_l=[]
#Initialize variable for shifting the anchor update between first measurements and first estimations
anchor_shift=60

# %%
#Data for video cows
anchorS=(1250,350)
videoIn_name="./Inputs/cows.avi"
path="./Outputs/"
videoOut_name=path+"cows-pf-yolo.avi"
#std in the prediction of particles for the object's position
std=10
#These are YOLO parameters
conf=0.8
nms=0.7
height, width, channels =224,320,3
blob_x,blob_y=224,320
#Motion model's speed in x and y directions
v_x=0.01
v_y=0.01

# %%
start_time = time.time()
for num in range(Tot):

    #List for averaging running outputs
    BB_l=[]
    ROI_l=[]
    anchor_l=[]
    xy_est_l=[]
    particles_l=[]
    #Counters
    yolo_det=0
    it=0
    n_resampling=0
    #A single program variables initialization
    anchor=anchorS
    #Initialization of measurements variables
    x_objMeasure,y_objMeasure=anchor[0],anchor[1]
    #BB variable initialization
    BB=0,0,0,0
    #Capture video where object tracking should be performed
    video = cv2.VideoCapture(videoIn_name)
    #Video output
    fourcc = cv2.VideoWriter_fourcc(*'XVID')
    video_output = cv2.VideoWriter(videoOut_name,fourcc,60,(frame_width,frame_height))
    #Particles Instantiation
    particles=ParticleFilter(frame_width,frame_height, n_particles)
    
    #Loop through the entire video
    while (True):
        #Take the video and break it frame by frame
        _,frame=video.read()
        #Check if frames are captured
        if(_ == False ): break

        it+=1

        #Particles prediction update
        particles.particles_update(v_x,v_y,std,frame_width,frame_height)
        particles_l.append(particles.particles.copy())
        anchor_l.append(anchor)
    
        #Coordinates of ROI around anchor
        dy1=int(anchor[1]-height/2)
        #if(dy1<0):dy1=0
        dy2=int(anchor[1]+height/2)
        #if (dy2>frame_height):dy2=frame_height
        dx1=int(anchor[0]-width/2)
        #if (dx1<0): dx1=0
        dx2=int(anchor[0]+width/2)
        #if (dx2>frame_width):dx2=frame_width

        frame_roi=frame[dy1:dy2,dx1:dx2]
        ROI_l.append((dx1,dy1,dx2,dy2))
            

        # Detecting objects
        scale=1/255
        blob = cv2.dnn.blobFromImage(frame_roi,scale,(blob_x, blob_y),(0, 0, 0), True, crop=False)
        net.setInput(blob)
        #Run forward pass to get predictions from output layers selected
        outputs = net.forward(output_layer_names)
        # Showing informations on the screen
        classes = []
        confidences = []
        boxes = []
        yolo_center=[]
        yolo_center_anchor_dist=[]

        #for each output of the YOLO last layers
        for output in outputs:
            for detection in output:
            #Each detection contains center point x,y,width,height,object probability
            #and 80 class probability
                scores = detection[5:]
                class_id = np.argmax(scores)
                confidence = scores[class_id]
                if confidence > conf:
                    print("step ",str(it),"confidence ",confidence,"\n")
                    #non normalized detected object's center, width and height 
                    center_x,center_y = int(detection[0] *blob_x),int(detection[1] * blob_y)
                    w,h = int(detection[2] * blob_x),int(detection[3] * blob_y)
                    # Rectangle coordinates for drawing
                    x,y = int(center_x - w / 2),int(center_y - h / 2)
                    boxes.append([x, y, w, h])
                    confidences.append(float(confidence))
                    classes.append(class_id)

                    #Get coordinates in initial video frame reference instead of 
                    #ROI reference
                    center_x_reverse=center_x+(anchor[0]-width/2)
                    center_y_reverse=center_y+(anchor[1]-height/2)
                    yolo_center.append((center_x_reverse,center_y_reverse))

        #Search and keep relevant bounding boxes given their scores 
        indexes = cv2.dnn.NMSBoxes(boxes, confidences, conf, nms)
        #Only compute the distances between anchor and the yolo predictions
        #if confidence is good and indexes is not empty
        if (len(indexes)!=0):
            yolo_center_anchor_dist=[math.sqrt((yolo_center[i][0]-anchor[0])**2+\
            (yolo_center[i][1]-anchor[1])**2) for i in range (len(yolo_center))\
                                    if i in indexes]
            #Keep the relevant indices in a list to retrieve the relevant index latter
            nms_indexes=[i for i in range (len(yolo_center)) if i in indexes]

            print("step ",str(it),"indexes ",indexes," nms ",nms_indexes,\
            " yolo_center ",yolo_center," distances ", yolo_center_anchor_dist, "\n")

            #Save and return the coordinates of the most suitable center and its BB
            #Keep the index of the minimum distance between prediction and anchor
            index=yolo_center_anchor_dist.index(min(yolo_center_anchor_dist))
            #Retrieve relevant index to select the yolo index and the corresponding BB
            index_yolo=nms_indexes[index]
            print("step ",str(it)," index ",index," index_yolo ",index_yolo,"\n")
            BB_x=int(boxes[index_yolo][0]+(anchor[0]-width/2))
            BB_y=int(boxes[index_yolo][1]+(anchor[1]-height/2))
            BB =BB_x,BB_y,boxes[index_yolo][2],boxes[index_yolo][3]

            #Update measurements and anchor  
            x_objMeasure,y_objMeasure=yolo_center[index_yolo][0],yolo_center[index_yolo][1]
            yolo_det+=1

        #Save BB in a list
        BB_l.append(BB)
        
        #Draw the ROI in red
        cv2.rectangle(frame, (dx1,dy1), (dx2,dy2), (0,0,250), 2)

        #Update the particles weights with the new measurements (Object center)
        particles.weigth_update(x_objMeasure,y_objMeasure)

        #Estimation of object center position
        x_estimation,y_estimation=particles.position_estimation()
        
        #Update the anchor with either the current measurements or the x and y estimates
        if it > anchor_shift:
            anchor=x_estimation,y_estimation
        else:
            anchor=x_objMeasure,y_objMeasure
        
        #Save the x and y estimated in a list
        xy_est_l.append((x_estimation,y_estimation))

        #Draw the particles
        particles.draw_box_particles(frame,BB,x_estimation,y_estimation)
        #Draw the position estimation
        cv2.circle(frame,(x_estimation,y_estimation),5,[0,255,0],3)

        #Resample the particles
        if (particles.effective_particles() < N_thresh):
            n_resampling+=1
            particles.resampling()

        if (num==Tot-1):
            video_output.write(frame)

        #if it==50:
        #    break
    
    yolo_det_l.append(yolo_det) 
    n_resampl_l.append(n_resampling)
    BB_avg.append(BB_l)
    xy_est_avg.append(xy_est_l)
    particles_avg.append(particles_l)
    ROI_avg.append(ROI_l)
    anchor_avg.append(anchor_l)
# Out:
# step  1 confidence  0.95814544
#
# step  1 indexes  [[0]]  nms  [0]  yolo_center  [(1291.0, 358.0)]  distances  [41.773197148410844]
#
# step  1  index  0  index_yolo  0
#
# step  2 confidence  0.9327465
#
# step  2 indexes  [[0]]  nms  [0]  yolo_center  [(1319.0, 364.0)]  distances  [28.635642126552707]
#
# step  2  index  0  index_yolo  0
#
# step  3 confidence  0.92327935
#
# step  3 indexes  [[0]]  nms  [0]  yolo_center  [(1339.0, 388.0)]  distances  [31.240998703626616]
#
# step  3  index  0  index_yolo  0
#
# step  11 confidence  0.8650678
#
# step  11 indexes  [[0]]  nms  [0]  yolo_center  [(1349.0, 379.0)]  distances  [13.45362404707371]
#
# step  11  index  0  index_yolo  0
#
# step  12 confidence  0.9655613
#
# step  12 indexes  [[0]]  nms  [0]  yolo_center  [(1353.0, 381.0)]  distances  [4.47213595499958]
#
# step  12  index  0  index_yolo  0
#
# step  13 confidence  0.8092951
#
# step  13 indexes  [[0]]  nms  [0]  yolo_center  [(1356.0, 384.0)]  distances  [4.242640687119285]
#
# step  13  index  0  index_yolo  0
#
# step  14 confidence  0.81820554
#
# step  14 indexes  [[0]]  nms  [0]  yolo_center  [(1359.0, 386.0)]  distances  [3.605551275463989]
#
# step  14  index  0  index_yolo  0
#
# step  15 confidence  0.87026924
#
# step  15 indexes  [[0]]  nms  [0]  yolo_center  [(1362.0, 387.0)]  distances  [3.1622776601683795]
#
# step  15  index  0  index_yolo  0
#
# step  16 confidence  0.9236498
#
# step  16 indexes  [[0]]  nms  [0]  yolo_center  [(1356.0, 381.0)]  distances  [8.48528137423857]
#
# step  16  index  0  index_yolo  0
#
# step  17 confidence  0.93096167
#
# step  17 indexes  [[0]]  nms  [0]  yolo_center  [(1358.0, 386.0)]  distances  [5.385164807134504]
#
# step  17  index  0  index_yolo  0
#
# step  18 confidence  0.8032349
#
# step  18 indexes  [[0]]  nms  [0]  yolo_center  [(1361.0, 388.0)]  distances  [3.605551275463989]
#
# step  18  index  0  index_yolo  0
#
# step  19 confidence  0.8418541
#
# step  19 indexes  [[0]]  nms  [0]  yolo_center  [(1365.0, 388.0)]  distances  [4.0]
#
# step  19  index  0  index_yolo  0
#
# step  20 confidence  0.8805596
#
# step  20 indexes  [[0]]  nms  [0]  yolo_center  [(1368.0, 390.0)]  distances  [3.605551275463989]
#
# step  20  index  0  index_yolo  0
#
# step  21 confidence  0.8340089
#
# step  21 confidence  0.8880665
#
# step  21 indexes  [[1]
#  [0]]  nms  [0, 1]  yolo_center  [(1359.0, 387.0), (1407.0, 401.0)]  distances  [9.486832980505138, 40.52159917870962]
#
# step  21  index  0  index_yolo  0
#
# step  25 confidence  0.8212493
#
# step  25 indexes  [[0]]  nms  [0]  yolo_center  [(1400.0, 410.0)]  distances  [47.01063709417264]
#
# step  25  index  0  index_yolo  0
#
# step  26 confidence  0.8196651
#
# step  26 confidence  0.8727994
#
# step  26 indexes  [[1]
#  [0]]  nms  [0, 1]  yolo_center  [(1380.0, 379.0), (1429.0, 403.0)]  distances  [36.89173349139343, 29.832867780352597]
#
# step  26  index  1  index_yolo  1
#
# step  73 confidence  0.85598755
#
# step  73 confidence  0.8139633
#
# step  73 indexes  [[0]
#  [1]]  nms  [0, 1]  yolo_center  [(1373.0, 371.0), (1444.0, 411.0)]  distances  [63.13477647065839, 18.35755975068582]
#
# step  73  index  1  index_yolo  1
#
# step  76 confidence  0.8255193
#
# step  76 indexes  [[0]]  nms  [0]  yolo_center  [(1319.0, 402.0)]  distances  [124.25779653607253]
#
# step  76  index  0  index_yolo  0
#
# step  86 confidence  0.81975794
#
# step  86 confidence  0.86583483
#
# step  86 indexes  [[1]
#  [0]]  nms  [0, 1]  yolo_center  [(1290.0, 409.0), (1413.0, 416.0)]  distances  [94.0, 29.832867780352597]
#
# step  86  index  1  index_yolo  1
#
# step  88 confidence  0.8642739
#
# step  88 confidence  0.8421179
#
# step  88 indexes  [[0]
#  [1]]  nms  [0, 1]  yolo_center  [(1280.0, 407.0), (1404.0, 419.0)]  distances  [94.19129471453293, 30.59411708155671]
#
# step  88  index  1  index_yolo  1
#
# step  118 confidence  0.8150959
#
# step  118 indexes  [[0]]  nms  [0]  yolo_center  [(1296.0, 412.0)]  distances  [108.2266141020775]
#
# step  118  index  0  index_yolo  0
#
# step  119 confidence  0.80427593
#
# step  119 indexes  [[0]]  nms  [0]  yolo_center  [(1295.0, 412.0)]  distances  [107.16809226630845]
#
# step  119  index  0  index_yolo  0
#
# step  123 confidence  0.83206964
#
# step  123 indexes  [[0]]  nms  [0]  yolo_center  [(1417.0, 426.0)]  distances  [27.892651361962706]
#
# step  123  index  0  index_yolo  0
#
# step  152 confidence  0.83687955
#
# step  152 indexes  [[0]]  nms  [0]  yolo_center  [(1305.0, 416.0)]  distances  [112.28535078094559]
#
# step  152  index  0  index_yolo  0
#
# step  153 confidence  0.8161091
#
# step  153 indexes  [[0]]  nms  [0]  yolo_center  [(1305.0, 416.0)]  distances  [111.22050170719426]
#
# step  153  index  0  index_yolo  0
#
# step  154 confidence  0.89411217
#
# step  154 indexes  [[0]]  nms  [0]  yolo_center  [(1304.0, 418.0)]  distances  [110.16351483136329]
#
# step  154  index  0  index_yolo  0
#
# step  159 confidence  0.8821101
#
# step  159 confidence  0.8797408
#
# step  159 indexes  [[0]
#  [1]]  nms  [0, 1]  yolo_center  [(1285.0, 420.0), (1408.0, 429.0)]  distances  [94.0, 30.364452901377952]
#
# step  159  index  1  index_yolo  1
#
# step  161 confidence  0.8610454
#
# step  161 confidence  0.9077208
#
# step  161 indexes  [[1]
#  [0]]  nms  [0, 1]  yolo_center  [(1287.0, 422.0), (1410.0, 429.0)]  distances  [94.00531899844816, 30.083217912982647]
#
# step  161  index  1  index_yolo  1
#
# step  162 confidence  0.8362709
#
# step  162 indexes  [[0]]  nms  [0]  yolo_center  [(1298.0, 419.0)]  distances  [110.3675676999362]
#
# step  162  index  0  index_yolo  0
#
# step  167 confidence  0.8115834
#
# step  167 indexes  [[0]]  nms  [0]  yolo_center  [(1416.0, 431.0)]  distances  [26.30589287593181]
#
# step  167  index  0  index_yolo  0
#
# step  171 confidence  0.8614152
#
# step  171 indexes  [[0]]  nms  [0]  yolo_center  [(1304.0, 421.0)]  distances  [111.36426715962351]
#
# step  171  index  0  index_yolo  0
#
# step  172 confidence  0.91787434
#
# step  172 indexes  [[0]]  nms  [0]  yolo_center  [(1304.0, 420.0)]  distances  [110.45361017187261]
#
# step  172  index  0  index_yolo  0
#
# step  173 confidence  0.8781178
#
# step  173 indexes  [[0]]  nms  [0]  yolo_center  [(1303.0, 420.0)]  distances  [109.45775440780794]
#
# step  173  index  0  index_yolo  0
#
# step  178 confidence  0.91689664
#
# step  178 confidence  0.92088825
#
# step  178 indexes  [[1]
#  [0]]  nms  [0, 1]  yolo_center  [(1274.0, 421.0), (1396.0, 424.0)]  distances  [92.34717104492157, 30.4138126514911]
#
# step  178  index  1  index_yolo  1
#
# step  179 confidence  0.8976392
#
# step  179 confidence  0.89483804
#
# step  179 confidence  0.93000627
#
# step  179 indexes  [[2]
#  [0]]  nms  [0, 2]  yolo_center  [(1282.0, 420.0), (1401.0, 426.0), (1404.0, 433.0)]  distances  [93.26306878931231, 29.614185789921695]
#
# step  179  index  1  index_yolo  2
#
# step  180 confidence  0.8110282
#
# step  180 confidence  0.80945253
#
# step  180 indexes  [[0]
#  [1]]  nms  [0, 1]  yolo_center  [(1293.0, 424.0), (1414.0, 424.0)]  distances  [94.13288479590966, 27.459060435491963]
#
# step  180  index  1  index_yolo  1
#
# step  203 confidence  0.8032143
#
# step  203 indexes  [[0]]  nms  [0]  yolo_center  [(1362.0, 390.0)]  distances  [59.682493245507096]
#
# step  203  index  0  index_yolo  0
#
# step  204 confidence  0.81895703
#
# step  204 indexes  [[0]]  nms  [0]  yolo_center  [(1360.0, 391.0)]  distances  [57.8013840664737]
#
# step  204  index  0  index_yolo  0
#
# step  205 confidence  0.81900704
#
# step  205 indexes  [[0]]  nms  [0]  yolo_center  [(1361.0, 409.0)]  distances  [45.5411901469428]
#
# step  205  index  0  index_yolo  0
#
# step  206 confidence  0.837319
#
# step  206 confidence  0.8429771
#
# step  206 indexes  [[1]
#  [0]]  nms  [0, 1]  yolo_center  [(1357.0, 410.0), (1416.0, 424.0)]  distances  [36.22154055254967, 25.079872407968907]
#
# step  206  index  1  index_yolo  1
#
# step  207 confidence  0.92022914
#
# step  207 indexes  [[0]]  nms  [0]  yolo_center  [(1273.0, 431.0)]  distances  [101.9803902718557]
#
# step  207  index  0  index_yolo  0
#
# step  208 confidence  0.89713824
#
# step  208 confidence  0.85533303
#
# step  208 indexes  [[0]
#  [1]]  nms  [0, 1]  yolo_center  [(1270.0, 431.0), (1399.0, 436.0)]  distances  [101.0, 39.05124837953327]
#
# step  208  index  1  index_yolo  1
#
# step  213 confidence  0.8011694
#
# step  213 indexes  [[0]]  nms  [0]  yolo_center  [(1422.0, 433.0)]  distances  [23.345235059857504]
#
# step  213  index  0  index_yolo  0
# step  217 confidence  0.8632263
#
# step  217 indexes  [[0]]  nms  [0]  yolo_center  [(1436.0, 432.0)]  distances  [15.033296378372908]
#
# step  217  index  0  index_yolo  0
#
# step  236 confidence  0.8490345
#
# step  236 indexes  [[0]]  nms  [0]  yolo_center  [(1366.0, 405.0)]  distances  [74.67261881037788]
#
# step  236  index  0  index_yolo  0
#
# step  237 confidence  0.87863696
#
# step  237 indexes  [[0]]  nms  [0]  yolo_center  [(1365.0, 407.0)]  distances  [74.33034373659252]
#
# step  237  index  0  index_yolo  0
#
# step  238 confidence  0.89922297
#
# step  238 indexes  [[0]]  nms  [0]  yolo_center  [(1363.0, 403.0)]  distances  [74.09453421137081]
#
# step  238  index  0  index_yolo  0
#
# step  239 confidence  0.91390616
#
# step  239 confidence  0.87020814
#
# step  239 indexes  [[0]
#  [1]]  nms  [0, 1]  yolo_center  [(1359.0, 400.0), (1307.0, 434.0)]  distances  [74.46475676452586, 121.1486689980538]
#
# step  239  index  0  index_yolo  0
#
# step  240 confidence  0.8722295
#
# step  240 confidence  0.89276785
#
# step  240 confidence  0.83438915
#
# step  240 indexes  [[1]
#  [0]]  nms  [0, 1]  yolo_center  [(1366.0, 399.0), (1303.0, 431.0), (1301.0, 433.0)]  distances  [62.16912416947821, 119.10499569707393]
#
# step  240  index  0  index_yolo  0
#
# step  241 confidence  0.8327662
#
# step  241 indexes  [[0]]  nms  [0]  yolo_center  [(1360.0, 413.0)]  distances  [56.71860364994893]
#
# step  241  index  0  index_yolo  0
#
# step  242 confidence  0.97104275
#
# step  242 confidence  0.9075419
#
# step  242 indexes  [[0]
#  [1]]  nms  [0, 1]  yolo_center  [(1351.0, 414.0), (1412.0, 442.0)]  distances  [37.0, 36.87817782917155]
#
# step  242  index  1  index_yolo  1
#
# step  243 confidence  0.8358669
#
# step  243 indexes  [[0]]  nms  [0]  yolo_center  [(1417.0, 432.0)]  distances  [24.596747752497688]
#
# step  243  index  0  index_yolo  0
#
# step  256 confidence  0.8755832
#
# step  256 indexes  [[0]]  nms  [0]  yolo_center  [(1299.0, 435.0)]  distances  [118.06777714516353]
#
# step  256  index  0  index_yolo  0
#
# step  257 confidence  0.8479497
#
# step  257 indexes  [[0]]  nms  [0]  yolo_center  [(1298.0, 434.0)]  distances  [117.01709276853532]
#
# step  257  index  0  index_yolo  0
#
# step  258 confidence  0.83602554
#
# step  258 indexes  [[0]]  nms  [0]  yolo_center  [(1297.0, 434.0)]  distances  [117.01709276853532]
#
# step  258  index  0  index_yolo  0
#
# step  260 confidence  0.833732
#
# step  260 indexes  [[0]]  nms  [0]  yolo_center  [(1292.0, 435.0)]  distances  [115.03912377969506]
#
# step  260  index  0  index_yolo  0
#
# step  262 confidence  0.8456926
#
# step  262 indexes  [[0]]  nms  [0]  yolo_center  [(1287.0, 434.0)]  distances  [113.01769772916099]
#
# step  262  index  0  index_yolo  0
#
# step  263 confidence  0.8682019
#
# step  263 confidence  0.9230224
#
# step  263 confidence  0.8106531
#
# step  263 indexes  [[1]
#  [0]
#  [2]]  nms  [0, 1, 2]  yolo_center  [(1351.0, 402.0), (1280.0, 436.0), (1414.0, 440.0)]  distances  [50.80354318352215, 112.0714058089752, 23.40939982143925]
#
# step  263  index  2  index_yolo  2
#
# step  299 confidence  0.8392469
#
# step  299 confidence  0.8038726
#
# step  299 indexes  [[0]
#  [1]]  nms  [0, 1]  yolo_center  [(1363.0, 409.0), (1296.0, 444.0)]  distances  [58.83026432033091, 117.06835610018618]
#
# step  299  index  0  index_yolo  0
#
# step  301 confidence  0.86161745
#
# step  301 indexes  [[0]]  nms  [0]  yolo_center  [(1357.0, 411.0)]  distances  [55.90169943749474]
#
# step  301  index  0  index_yolo  0
#
# step  302 confidence  0.8778171
#
# step  302 confidence  0.866382
#
# step  302 indexes  [[0]
#  [1]]  nms  [0, 1]  yolo_center  [(1360.0, 424.0), (1423.0, 445.0)]  distances  [41.97618372363071, 25.059928172283335]
#
# step  302  index  1  index_yolo  1
#
# step  303 confidence  0.87677085
#
# step  303 indexes  [[0]]  nms  [0]  yolo_center  [(1358.0, 412.0)]  distances  [57.245087125446844]
#
# step  303  index  0  index_yolo  0
#
# step  304 confidence  0.85909265
#
# step  304 confidence  0.937713
#
# step  304 confidence  0.8461763
#
# step  304 indexes  [[1]
#  [0]
#  [2]]  nms  [0, 1, 2]  yolo_center  [(1286.0, 443.0), (1358.0, 427.0), (1418.0, 444.0)]  distances  [111.5437134042076, 39.319206502675, 24.186773244895647]
#
# step  304  index  2  index_yolo  2
#
# step  305 confidence  0.8859698
#
# step  305 indexes  [[0]]  nms  [0]  yolo_center  [(1357.0, 428.0)]  distances  [37.013511046643494]
#
# step  305  index  0  index_yolo  0
#
# step  306 confidence  0.9124038
#
# step  306 indexes  [[0]]  nms  [0]  yolo_center  [(1407.0, 452.0)]  distances  [38.948684188300895]
#
# step  306  index  0  index_yolo  0
#
# step  307 confidence  0.847593
#
# step  307 indexes  [[0]]  nms  [0]  yolo_center  [(1355.0, 429.0)]  distances  [36.6742416417845]
#
# step  307  index  0  index_yolo  0
#
# step  308 confidence  0.8850783
#
# step  308 indexes  [[0]]  nms  [0]  yolo_center  [(1272.0, 452.0)]  distances  [102.96115772464877]
#
# step  308  index  0  index_yolo  0
#
# step  309 confidence  0.8866942
#
# step  309 confidence  0.90593547
#
# step  309 indexes  [[1]
#  [0]]  nms  [0, 1]  yolo_center  [(1263.0, 453.0), (1393.0, 457.0)]  distances  [96.54014708917737, 44.40720662234904]
#
# step  309  index  1  index_yolo  1
#
# step  310 confidence  0.8849409
#
# step  310 confidence  0.800103
#
# step  310 indexes  [[0]
#  [1]]  nms  [0, 1]  yolo_center  [(1267.0, 456.0), (1396.0, 459.0)]  distances  [100.80674580602232, 37.20215047547655]
#
# step  310  index  1  index_yolo  1
#
# step  311 confidence  0.88681704
#
# step  311 confidence  0.92428195
#
# step  311 confidence  0.96365505
#
# step  311 indexes  [[2]
#  [1]
#  [0]]  nms  [0, 1, 2]  yolo_center  [(1358.0, 423.0), (1284.0, 448.0), (1408.0, 456.0)]  distances  [32.802438933713454, 94.00531899844816, 30.805843601498726]
#
# step  311  index  2  index_yolo  2
#
# step  313 confidence  0.8054833
#
# step  313 indexes  [[0]]  nms  [0]  yolo_center  [(1422.0, 453.0)]  distances  [22.561028345356956]
#
# step  313  index  0  index_yolo  0
#
# step  326 confidence  0.8115357
#
# step  326 indexes  [[0]]  nms  [0]  yolo_center  [(1377.0, 421.0)]  distances  [53.823786563191554]
#
# step  326  index  0  index_yolo  0
#
# step  328 confidence  0.9073425
#
# step  328 confidence  0.8457753
#
# step  328 confidence  0.9125914
#
# step  328 indexes  [[2]
#  [0]
#  [1]]  nms  [0, 1, 2]  yolo_center  [(1374.0, 417.0), (1298.0, 454.0), (1435.0, 458.0)]  distances  [49.20365840057018, 115.2128465059344, 24.596747752497688]
#
# step  328  index  2  index_yolo  2
#
# step  329 confidence  0.8419794
#
# step  329 confidence  0.85477084
#
# step  329 confidence  0.82240456
#
# step  329 indexes  [[1]
#  [0]
#  [2]]  nms  [0, 1, 2]  yolo_center  [(1377.0, 421.0), (1304.0, 453.0), (1442.0, 460.0)]  distances  [54.08326913195984, 118.01694793545543, 21.93171219946131]
#
# step  329  index  2  index_yolo  2
#
# step  357 confidence  0.82466936
#
# step  357 confidence  0.8235126
#
# step  357 indexes  [[0]
#  [1]]  nms  [0, 1]  yolo_center  [(1398.0, 427.0), (1461.0, 470.0)]  distances  [53.600373133029585, 22.825424421026653]
#
# step  357  index  1  index_yolo  1
#
# step  370 confidence  0.81351
#
# step  370 indexes  [[0]]  nms  [0]  yolo_center  [(1340.0, 466.0)]  distances  [121.03718436910205]
#
# step  370  index  0  index_yolo  0
#
# step  373 confidence  0.8316901
#
# step  373 indexes  [[0]]  nms  [0]  yolo_center  [(1474.0, 478.0)]  distances  [22.360679774997898]
#
# step  373  index  0  index_yolo  0
#
# step  409 confidence  0.8793575
#
# step  409 confidence  0.9248649
#
# step  409 indexes  [[1]
#  [0]]  nms  [0, 1]  yolo_center  [(1450.0, 449.0), (1494.0, 486.0)]  distances  [37.64306044943742, 21.540659228538015]
#
# step  409  index  1  index_yolo  1
#
# step  410 confidence  0.8456664
#
# step  410 indexes  [[0]]  nms  [0]  yolo_center  [(1440.0, 450.0)]  distances  [48.60041152089147]
#
# step  410  index  0  index_yolo  0
#
# step  411 confidence  0.8402205
#
# step  411 confidence  0.81678545
#
# step  411 indexes  [[0]
#  [1]]  nms  [0, 1]  yolo_center  [(1452.0, 447.0), (1493.0, 485.0)]  distances  [35.608987629529715, 21.470910553583888]
#
# step  411  index  1  index_yolo  1
#
# step  412 confidence  0.86771214
#
# step  412 confidence  0.85452527
#
# step  412 indexes  [[0]
#  [1]]  nms  [0, 1]  yolo_center  [(1443.0, 450.0), (1500.0, 488.0)]  distances  [48.010415536631214, 20.591260281974]
#
# step  412  index  1  index_yolo  1
# step  461 confidence  0.85928047
#
# step  461 indexes  [[0]]  nms  [0]  yolo_center  [(1520.0, 480.0)]  distances  [21.540659228538015]
#
# step  461  index  0  index_yolo  0
#
# step  462 confidence  0.80291593
#
# step  462 indexes  [[0]]  nms  [0]  yolo_center  [(1388.0, 475.0)]  distances  [119.41942890501528]
#
# step  462  index  0  index_yolo  0
#
# step  463 confidence  0.924453
#
# step  463 indexes  [[0]]  nms  [0]  yolo_center  [(1389.0, 474.0)]  distances  [123.25988804148737]
#
# step  463  index  0  index_yolo  0
#
# step  464 confidence  0.8833646
#
# step  464 indexes  [[0]]  nms  [0]  yolo_center  [(1389.0, 474.0)]  distances  [122.2620137246234]
#
# step  464  index  0  index_yolo  0
#
# step  469 confidence  0.81925374
#
# step  469 confidence  0.8799132
#
# step  469 indexes  [[1]
#  [0]]  nms  [0, 1]  yolo_center  [(1443.0, 437.0), (1506.0, 478.0)]  distances  [57.62811813689564, 27.294688127912362]
#
# step  469  index  1  index_yolo  1
#
# step  470 confidence  0.8246545
#
# step  470 indexes  [[0]]  nms  [0]  yolo_center  [(1515.0, 476.0)]  distances  [24.515301344262525]
#
# step  470  index  0  index_yolo  0
#
# step  471 confidence  0.8016133
#
# step  471 indexes  [[0]]  nms  [0]  yolo_center  [(1450.0, 434.0)]  distances  [69.81403870282824]
#
# step  471  index  0  index_yolo  0
#
# step  472 confidence  0.87776285
#
# step  472 indexes  [[0]]  nms  [0]  yolo_center  [(1384.0, 468.0)]  distances  [125.14391715141412]
#
# step  472  index  0  index_yolo  0
#
# step  473 confidence  0.87977356
#
# step  473 indexes  [[0]]  nms  [0]  yolo_center  [(1383.0, 468.0)]  distances  [124.14507642270796]
#
# step  473  index  0  index_yolo  0
#
# step  476 confidence  0.8437477
#
# step  476 indexes  [[0]]  nms  [0]  yolo_center  [(1357.0, 468.0)]  distances  [103.04368005850722]
#
# step  476  index  0  index_yolo  0
#
# step  477 confidence  0.92498815
#
# step  477 confidence  0.91110784
#
# step  477 indexes  [[0]
#  [1]]  nms  [0, 1]  yolo_center  [(1298.0, 463.0), (1395.0, 435.0)]  distances  [69.1158447825099, 36.87817782917155]
#
# step  477  index  1  index_yolo  1
#
# step  478 confidence  0.85684377
#
# step  478 confidence  0.930774
#
# step  478 confidence  0.930292
#
# step  478 indexes  [[1]
#  [2]]  nms  [1, 2]  yolo_center  [(1397.0, 442.0), (1303.0, 476.0), (1397.0, 429.0)]  distances  [72.73238618387272, 34.655446902326915]
#
# step  478  index  1  index_yolo  2
#
# step  479 confidence  0.83716017
#
# step  479 confidence  0.94531155
#
# step  479 confidence  0.9215526
#
# step  479 indexes  [[1]
#  [2]]  nms  [1, 2]  yolo_center  [(1402.0, 437.0), (1307.0, 472.0), (1403.0, 424.0)]  distances  [79.12016177940993, 29.732137494637012]
#
# step  479  index  1  index_yolo  2
#
# step  480 confidence  0.89025956
#
# step  480 confidence  0.9235266
#
# step  480 indexes  [[1]
#  [0]]  nms  [0, 1]  yolo_center  [(1412.0, 439.0), (1314.0, 484.0)]  distances  [20.591260281974, 97.082439194738]
#
# step  480  index  0  index_yolo  0
#
# step  481 confidence  0.8930884
#
# step  481 confidence  0.8688695
#
# step  481 indexes  [[0]
#  [1]]  nms  [0, 1]  yolo_center  [(1418.0, 457.0), (1320.0, 491.0)]  distances  [28.844410203711913, 100.43903623591775]
#
# step  481  index  0  index_yolo  0
#
# step  482 confidence  0.8473925
#
# step  482 indexes  [[0]]  nms  [0]  yolo_center  [(1326.0, 473.0)]  distances  [92.69843580125827]
#
# step  482  index  0  index_yolo  0
#
# step  483 confidence  0.90095264
#
# step  483 indexes  [[0]]  nms  [0]  yolo_center  [(1326.0, 473.0)]  distances  [91.0823802938856]
#
# step  483  index  0  index_yolo  0
#
# step  484 confidence  0.9176705
#
# step  484 confidence  0.8999442
#
# step  484 indexes  [[0]
#  [1]]  nms  [0, 1]  yolo_center  [(1423.0, 448.0), (1325.0, 482.0)]  distances  [16.64331697709324, 87.64131445842195]
#
# step  484  index  0  index_yolo  0
#
# step  485 confidence  0.8867644
#
# step  485 indexes  [[0]]  nms  [0]  yolo_center  [(1330.0, 477.0)]  distances  [89.02246907382428]
#
# step  485  index  0  index_yolo  0
#
# step  486 confidence  0.866425
#
# step  486 indexes  [[0]]  nms  [0]  yolo_center  [(1327.0, 478.0)]  distances  [88.32326986700618]
#
# step  486  index  0  index_yolo  0
#
# step  487 confidence  0.91360915
#
# step  487 confidence  0.8930837
#
# step  487 indexes  [[0]
#  [1]]  nms  [0, 1]  yolo_center  [(1421.0, 446.0), (1325.0, 481.0)]  distances  [16.401219466856727, 86.68333173107735]
#
# step  487  index  0  index_yolo  0
#
# step  488 confidence  0.8050735
#
# step  488 indexes  [[0]]  nms  [0]  yolo_center  [(1330.0, 472.0)]  distances  [89.02246907382428]
#
# step  488  index  0  index_yolo  0
#
# step  489 confidence  0.82054687
#
# step  489 confidence  0.8555639
#
# step  489 indexes  [[1]
#  [0]]  nms  [0, 1]  yolo_center  [(1416.0, 438.0), (1330.0, 469.0)]  distances  [9.486832980505138, 91.67878707749138]
#
# step  489  index  0  index_yolo  0
#
# step  490 confidence  0.83024853
#
# step  490 indexes  [[0]]  nms  [0]  yolo_center  [(1414.0, 437.0)]  distances  [6.708203932499369]
#
# step  490  index  0  index_yolo  0
#
# step  491 confidence  0.8216971
#
# step  491 indexes  [[0]]  nms  [0]  yolo_center  [(1326.0, 466.0)]  distances  [93.30058949438637]
#
# step  491  index  0  index_yolo  0
#
# step  493 confidence  0.8852849
#
# step  493 indexes  [[0]]  nms  [0]  yolo_center  [(1324.0, 467.0)]  distances  [92.02716990106781]
#
# step  493  index  0  index_yolo  0
#
# step  494 confidence  0.9461002
#
# step  494 indexes  [[0]]  nms  [0]  yolo_center  [(1321.0, 468.0)]  distances  [91.706052144883]
#
# step  494  index  0  index_yolo  0
#
# step  495 confidence  0.9148567
#
# step  495 indexes  [[0]]  nms  [0]  yolo_center  [(1319.0, 468.0)]  distances  [89.49301648732151]
#
# step  495  index  0  index_yolo  0
#
# step  496 confidence  0.882787
#
# step  496 indexes  [[0]]  nms  [0]  yolo_center  [(1316.0, 465.0)]  distances  [85.44003745317531]
#
# step  496  index  0  index_yolo  0
#
# step  497 confidence  0.8849638
#
# step  497 indexes  [[0]]  nms  [0]  yolo_center  [(1312.0, 467.0)]  distances  [81.60882305241266]
#
# step  497  index  0  index_yolo  0
#
# step  498 confidence  0.97898805
#
# step  498 confidence  0.8317598
#
# step  498 indexes  [[0]
#  [1]]  nms  [0, 1]  yolo_center  [(1290.0, 465.0), (1381.0, 421.0)]  distances  [64.51356446515724, 37.8021163428716]
#
# step  498  index  1  index_yolo  1
#
# step  499 confidence  0.8044152
#
# step  499 confidence  0.97134584
#
# step  499 confidence  0.9722331
#
# step  499 indexes  [[2]
#  [1]]  nms  [1, 2]  yolo_center  [(1385.0, 430.0), (1297.0, 463.0), (1387.0, 416.0)]  distances  [66.85057965343307, 35.608987629529715]
#
# step  499  index  1  index_yolo  2
#
# step  500 confidence  0.9358173
#
# step  500 indexes  [[0]]  nms  [0]  yolo_center  [(1299.0, 459.0)]  distances  [76.69419795525604]
#
# step  500  index  0  index_yolo  0
#
# step  501 confidence  0.9147885
#
# step  501 confidence  0.82683533
#
# step  501 indexes  [[0]
#  [1]]  nms  [0, 1]  yolo_center  [(1303.0, 473.0), (1397.0, 415.0)]  distances  [89.20201791439474, 23.345235059857504]
#
# step  501  index  1  index_yolo  1
#
# step  502 confidence  0.85146594
#
# step  502 confidence  0.97173405
#
# step  502 indexes  [[1]
#  [0]]  nms  [0, 1]  yolo_center  [(1405.0, 439.0), (1309.0, 471.0)]  distances  [30.479501308256342, 93.81364506296512]
#
# step  502  index  0  index_yolo  0
#
# step  503 confidence  0.9478258
#
# step  503 indexes  [[0]]  nms  [0]  yolo_center  [(1313.0, 477.0)]  distances  [95.69221493935649]
#
# step  503  index  0  index_yolo  0
#
# step  504 confidence  0.9326519
#
# step  504 indexes  [[0]]  nms  [0]  yolo_center  [(1319.0, 460.0)]  distances  [88.95504482602435]
#
# step  504  index  0  index_yolo  0
#
# step  506 confidence  0.8095914
#
# step  506 confidence  0.8930446
#
# step  506 indexes  [[1]
#  [0]]  nms  [0, 1]  yolo_center  [(1411.0, 426.0), (1314.0, 459.0)]  distances  [18.681541692269406, 83.81527307120105]
#
# step  506  index  0  index_yolo  0
#
# step  507 confidence  0.8120117
#
# step  507 confidence  0.84295976
#
# step  507 indexes  [[1]
#  [0]]  nms  [0, 1]  yolo_center  [(1417.0, 429.0), (1318.0, 459.0)]  distances  [15.033296378372908, 89.5377015563835]
#
# step  507  index  0  index_yolo  0
#
# step  508 confidence  0.8147103
#
# step  508 indexes  [[0]]  nms  [0]  yolo_center  [(1323.0, 459.0)]  distances  [92.35799911215054]
#
# step  508  index  0  index_yolo  0
# step  510 confidence  0.821316
#
# step  510 indexes  [[0]]  nms  [0]  yolo_center  [(1328.0, 457.0)]  distances  [91.0823802938856]
#
# step  510  index  0  index_yolo  0
#
# step  511 confidence  0.8610138
#
# step  511 confidence  0.9261849
#
# step  511 indexes  [[1]
#  [0]]  nms  [0, 1]  yolo_center  [(1418.0, 426.0), (1325.0, 458.0)]  distances  [7.615773105863909, 90.75791976461338]
#
# step  511  index  0  index_yolo  0
#
# step  512 confidence  0.818053
#
# step  512 confidence  0.886293
#
# step  512 indexes  [[1]
#  [0]]  nms  [0, 1]  yolo_center  [(1419.0, 422.0), (1327.0, 456.0)]  distances  [7.0710678118654755, 91.706052144883]
#
# step  512  index  0  index_yolo  0
#
# step  513 confidence  0.820643
#
# step  513 indexes  [[0]]  nms  [0]  yolo_center  [(1329.0, 455.0)]  distances  [92.97311439335567]
#
# step  513  index  0  index_yolo  0
#
# step  514 confidence  0.86669165
#
# step  514 indexes  [[0]]  nms  [0]  yolo_center  [(1422.0, 420.0)]  distances  [4.123105625617661]
#
# step  514  index  0  index_yolo  0
#
# step  515 confidence  0.8853689
#
# step  515 indexes  [[0]]  nms  [0]  yolo_center  [(1417.0, 420.0)]  distances  [3.0]
#
# step  515  index  0  index_yolo  0
#
# step  516 confidence  0.8579394
#
# step  516 indexes  [[0]]  nms  [0]  yolo_center  [(1416.0, 418.0)]  distances  [3.605551275463989]
#
# step  516  index  0  index_yolo  0
#
# step  519 confidence  0.8198047
#
# step  519 indexes  [[0]]  nms  [0]  yolo_center  [(1326.0, 470.0)]  distances  [103.24727599312246]
#
# step  519  index  0  index_yolo  0
#
# step  520 confidence  0.8471944
#
# step  520 indexes  [[0]]  nms  [0]  yolo_center  [(1325.0, 471.0)]  distances  [104.62313319720452]
#
# step  520  index  0  index_yolo  0
#
# step  521 confidence  0.82349986
#
# step  521 confidence  0.8589859
#
# step  521 indexes  [[1]
#  [0]]  nms  [0, 1]  yolo_center  [(1419.0, 417.0), (1325.0, 472.0)]  distances  [7.0, 102.9271587094485]
#
# step  521  index  0  index_yolo  0
#
# step  523 confidence  0.8542423
#
# step  523 indexes  [[0]]  nms  [0]  yolo_center  [(1422.0, 415.0)]  distances  [5.385164807134504]
#
# step  523  index  0  index_yolo  0
#
# step  525 confidence  0.8183524
#
# step  525 indexes  [[0]]  nms  [0]  yolo_center  [(1331.0, 469.0)]  distances  [105.8158778255891]
#
# step  525  index  0  index_yolo  0
#
# step  528 confidence  0.85793823
#
# step  528 indexes  [[0]]  nms  [0]  yolo_center  [(1327.0, 446.0)]  distances  [93.96275858019496]
#
# step  528  index  0  index_yolo  0
#
# step  529 confidence  0.90423185
#
# step  529 indexes  [[0]]  nms  [0]  yolo_center  [(1325.0, 448.0)]  distances  [91.09335870413386]
#
# step  529  index  0  index_yolo  0
#
# step  530 confidence  0.851607
#
# step  530 indexes  [[0]]  nms  [0]  yolo_center  [(1320.0, 452.0)]  distances  [87.28115489611719]
#
# step  530  index  0  index_yolo  0
#
# step  531 confidence  0.92569274
#
# step  531 confidence  0.8909543
#
# step  531 indexes  [[0]
#  [1]]  nms  [0, 1]  yolo_center  [(1293.0, 440.0), (1385.0, 407.0)]  distances  [62.39390995922599, 50.0]
#
# step  531  index  1  index_yolo  1
#
# step  532 confidence  0.96913046
#
# step  532 confidence  0.94401723
#
# step  532 indexes  [[0]
#  [1]]  nms  [0, 1]  yolo_center  [(1300.0, 439.0), (1390.0, 404.0)]  distances  [62.07253821135398, 47.20169488482379]
#
# step  532  index  1  index_yolo  1
#
# step  533 confidence  0.82676965
#
# step  533 confidence  0.9260388
#
# step  533 confidence  0.90065616
#
# step  533 indexes  [[1]
#  [2]
#  [0]]  nms  [0, 1, 2]  yolo_center  [(1396.0, 423.0), (1300.0, 452.0), (1395.0, 392.0)]  distances  [24.73863375370596, 75.58438992278762, 43.56604182158393]
#
# step  533  index  0  index_yolo  0
#
# step  534 confidence  0.93459064
#
# step  534 indexes  [[0]]  nms  [0]  yolo_center  [(1307.0, 448.0)]  distances  [80.00624975587844]
#
# step  534  index  0  index_yolo  0
#
# step  535 confidence  0.9694528
#
# step  535 indexes  [[0]]  nms  [0]  yolo_center  [(1308.0, 445.0)]  distances  [82.21921916437786]
#
# step  535  index  0  index_yolo  0
#
# step  536 confidence  0.866661
#
# step  536 confidence  0.9378388
#
# step  536 confidence  0.8776049
#
# step  536 indexes  [[1]
#  [2]]  nms  [1, 2]  yolo_center  [(1401.0, 410.0), (1305.0, 446.0), (1399.0, 400.0)]  distances  [78.10889834071403, 29.0]
#
# step  536  index  1  index_yolo  2
#
# step  537 confidence  0.96109986
#
# step  537 indexes  [[0]]  nms  [0]  yolo_center  [(1309.0, 444.0)]  distances  [85.23496934944014]
#
# step  537  index  0  index_yolo  0
#
# step  538 confidence  0.91289693
#
# step  538 confidence  0.835404
#
# step  538 indexes  [[0]
#  [1]]  nms  [0, 1]  yolo_center  [(1305.0, 446.0), (1399.0, 397.0)]  distances  [79.47955712005447, 28.284271247461902]
#
# step  538  index  1  index_yolo  1
#
# step  539 confidence  0.8875136
#
# step  539 confidence  0.95303327
#
# step  539 indexes  [[1]
#  [0]]  nms  [0, 1]  yolo_center  [(1410.0, 427.0), (1311.0, 459.0)]  distances  [29.832867780352597, 97.082439194738]
#
# step  539  index  0  index_yolo  0
#
# step  540 confidence  0.9002935
#
# step  540 indexes  [[0]]  nms  [0]  yolo_center  [(1317.0, 455.0)]  distances  [99.56907150315303]
#
# step  540  index  0  index_yolo  0
#
# step  541 confidence  0.8737425
#
# step  541 indexes  [[0]]  nms  [0]  yolo_center  [(1317.0, 458.0)]  distances  [99.86490875177326]
#
# step  541  index  0  index_yolo  0
#
# step  542 confidence  0.89157856
#
# step  542 confidence  0.89649254
#
# step  542 indexes  [[1]
#  [0]]  nms  [0, 1]  yolo_center  [(1413.0, 426.0), (1314.0, 460.0)]  distances  [28.42534080710379, 98.4733466477097]
#
# step  542  index  0  index_yolo  0
#
# step  543 confidence  0.9124166
#
# step  543 indexes  [[0]]  nms  [0]  yolo_center  [(1317.0, 444.0)]  distances  [90.82400563727631]
#
# step  543  index  0  index_yolo  0
#
# step  544 confidence  0.8891821
#
# step  544 confidence  0.8955965
#
# step  544 indexes  [[1]
#  [0]]  nms  [0, 1]  yolo_center  [(1415.0, 414.0), (1316.0, 443.0)]  distances  [17.029386365926403, 87.31551981177229]
#
# step  544  index  0  index_yolo  0
#
# step  545 confidence  0.8052762
#
# step  545 confidence  0.9045169
#
# step  545 indexes  [[1]
#  [0]]  nms  [0, 1]  yolo_center  [(1420.0, 412.0), (1321.0, 444.0)]  distances  [14.035668847618199, 90.47651629014017]
#
# step  545  index  0  index_yolo  0
#
# step  546 confidence  0.922713
#
# step  546 confidence  0.9072629
#
# step  546 indexes  [[0]
#  [1]]  nms  [0, 1]  yolo_center  [(1424.0, 414.0), (1328.0, 441.0)]  distances  [7.0710678118654755, 93.30058949438637]
#
# step  546  index  0  index_yolo  0
#
# step  547 confidence  0.90013987
#
# step  547 confidence  0.8503573
#
# step  547 indexes  [[0]
#  [1]]  nms  [0, 1]  yolo_center  [(1426.0, 414.0), (1331.0, 440.0)]  distances  [6.0, 92.72000862812729]
#
# step  547  index  0  index_yolo  0
#
# step  548 confidence  0.81410694
#
# step  548 indexes  [[0]]  nms  [0]  yolo_center  [(1332.0, 440.0)]  distances  [95.60334722173695]
#
# step  548  index  0  index_yolo  0
#
# step  549 confidence  0.9206719
#
# step  549 indexes  [[0]]  nms  [0]  yolo_center  [(1334.0, 440.0)]  distances  [95.33624704172071]
#
# step  549  index  0  index_yolo  0
#
# step  550 confidence  0.8562471
#
# step  550 indexes  [[0]]  nms  [0]  yolo_center  [(1332.0, 439.0)]  distances  [93.86160024205851]
#
# step  550  index  0  index_yolo  0
#
# step  551 confidence  0.8012477
#
# step  551 confidence  0.89484614
#
# step  551 indexes  [[1]
#  [0]]  nms  [0, 1]  yolo_center  [(1427.0, 412.0), (1331.0, 442.0)]  distances  [8.602325267042627, 92.44457799135652]
#
# step  551  index  0  index_yolo  0
#
# step  552 confidence  0.8863674
#
# step  552 indexes  [[0]]  nms  [0]  yolo_center  [(1333.0, 440.0)]  distances  [93.40770846134703]
#
# step  552  index  0  index_yolo  0
#
# step  553 confidence  0.8381222
#
# step  553 indexes  [[0]]  nms  [0]  yolo_center  [(1331.0, 443.0)]  distances  [93.00537618869137]
#
# step  553  index  0  index_yolo  0
#
# step  554 confidence  0.88999873
#
# step  554 indexes  [[0]]  nms  [0]  yolo_center  [(1326.0, 443.0)]  distances  [90.24965373894794]
#
# step  554  index  0  index_yolo  0
#
# step  555 confidence  0.8438728
#
# step  555 confidence  0.8885841
#
# step  555 indexes  [[1]
#  [0]]  nms  [0, 1]  yolo_center  [(1309.0, 451.0), (1406.0, 389.0)]  distances  [80.32434251209281, 41.677331968349414]
#
# step  555  index  1  index_yolo  1
# step  557 confidence  0.8374702
#
# step  557 indexes  [[0]]  nms  [0]  yolo_center  [(1288.0, 428.0)]  distances  [54.037024344425184]
#
# step  557  index  0  index_yolo  0
#
# step  561 confidence  0.84967244
#
# step  561 confidence  0.83432037
#
# step  561 indexes  [[0]
#  [1]]  nms  [0, 1]  yolo_center  [(1263.0, 430.0), (1195.0, 469.0)]  distances  [26.1725046566048, 102.95630140987001]
#
# step  561  index  0  index_yolo  0
#
# step  563 confidence  0.8161851
#
# step  563 confidence  0.8241069
#
# step  563 indexes  [[1]
#  [0]]  nms  [0, 1]  yolo_center  [(1254.0, 432.0), (1184.0, 470.0)]  distances  [22.360679774997898, 101.13357503816425]
#
# step  563  index  0  index_yolo  0
#
# step  564 confidence  0.8374012
#
# step  564 indexes  [[0]]  nms  [0]  yolo_center  [(1174.0, 472.0)]  distances  [96.60745312862771]
#
# step  564  index  0  index_yolo  0
#
# step  569 confidence  0.8356444
#
# step  569 indexes  [[0]]  nms  [0]  yolo_center  [(1170.0, 475.0)]  distances  [78.79086241436883]
#
# step  569  index  0  index_yolo  0
#
# step  570 confidence  0.8959127
#
# step  570 indexes  [[0]]  nms  [0]  yolo_center  [(1147.0, 473.0)]  distances  [69.58448102845921]
#
# step  570  index  0  index_yolo  0
#
# step  571 confidence  0.8799201
#
# step  571 indexes  [[0]]  nms  [0]  yolo_center  [(1143.0, 474.0)]  distances  [67.47592163134935]
#
# step  571  index  0  index_yolo  0
#
# step  573 confidence  0.9407979
#
# step  573 indexes  [[0]]  nms  [0]  yolo_center  [(1147.0, 475.0)]  distances  [51.62363799656123]
#
# step  573  index  0  index_yolo  0
#
# step  574 confidence  0.9000769
#
# step  574 indexes  [[0]]  nms  [0]  yolo_center  [(1142.0, 477.0)]  distances  [44.721359549995796]
#
# step  574  index  0  index_yolo  0
#
# step  575 confidence  0.8276795
#
# step  575 indexes  [[0]]  nms  [0]  yolo_center  [(1120.0, 492.0)]  distances  [31.240998703626616]
#
# step  575  index  0  index_yolo  0
#
# step  578 confidence  0.83370554
#
# step  578 indexes  [[0]]  nms  [0]  yolo_center  [(1106.0, 481.0)]  distances  [17.4928556845359]
#
# step  578  index  0  index_yolo  0
#
# step  579 confidence  0.9275572
#
# step  579 indexes  [[0]]  nms  [0]  yolo_center  [(1106.0, 481.0)]  distances  [10.816653826391969]
#
# step  579  index  0  index_yolo  0
#
# step  580 confidence  0.9171765
#
# step  580 indexes  [[0]]  nms  [0]  yolo_center  [(1103.0, 481.0)]  distances  [7.615773105863909]
#
# step  580  index  0  index_yolo  0
#
# step  582 confidence  0.8007678
#
# step  582 indexes  [[0]]  nms  [0]  yolo_center  [(1096.0, 480.0)]  distances  [6.082762530298219]
#
# step  582  index  0  index_yolo  0
#
# step  594 confidence  0.94053733
#
# step  594 confidence  0.8529188
#
# step  594 indexes  [[0]]  nms  [0]  yolo_center  [(1116.0, 480.0), (1120.0, 484.0)]  distances  [22.0]
#
# step  594  index  0  index_yolo  0
#
# step  595 confidence  0.95157397
#
# step  595 confidence  0.9262109
#
# step  595 indexes  [[0]]  nms  [0]  yolo_center  [(1120.0, 480.0), (1124.0, 475.0)]  distances  [24.0]
#
# step  595  index  0  index_yolo  0
#
# step  605 confidence  0.9031608
#
# step  605 indexes  [[0]]  nms  [0]  yolo_center  [(1155.0, 486.0)]  distances  [35.510561809129406]
#
# step  605  index  0  index_yolo  0
#
# step  606 confidence  0.864495
#
# step  606 indexes  [[0]]  nms  [0]  yolo_center  [(1158.0, 486.0)]  distances  [35.35533905932738]
#
# step  606  index  0  index_yolo  0
#
# step  608 confidence  0.83409625
#
# step  608 indexes  [[0]]  nms  [0]  yolo_center  [(1166.0, 477.0)]  distances  [30.805843601498726]
#
# step  608  index  0  index_yolo  0
#
# step  609 confidence  0.9359976
#
# step  609 confidence  0.9582314
#
# step  609 indexes  [[1]]  nms  [1]  yolo_center  [(1179.0, 487.0), (1183.0, 490.0)]  distances  [28.861739379323623]
#
# step  609  index  0  index_yolo  1
#
# step  610 confidence  0.86752975
#
# step  610 confidence  0.8178981
#
# step  610 indexes  [[0]]  nms  [0]  yolo_center  [(1187.0, 484.0), (1191.0, 489.0)]  distances  [22.0]
#
# step  610  index  0  index_yolo  0
#
# step  611 confidence  0.80215853
#
# step  611 indexes  [[0]]  nms  [0]  yolo_center  [(1197.0, 481.0)]  distances  [17.11724276862369]
#
# step  611  index  0  index_yolo  0
#
# step  612 confidence  0.8578963
#
# step  612 indexes  [[0]]  nms  [0]  yolo_center  [(1204.0, 481.0)]  distances  [17.029386365926403]
#
# step  612  index  0  index_yolo  0
#
# step  615 confidence  0.82405216
#
# step  615 indexes  [[0]]  nms  [0]  yolo_center  [(1216.0, 477.0)]  distances  [15.524174696260024]
#
# step  615  index  0  index_yolo  0
#
# step  619 confidence  0.8594934
#
# step  619 indexes  [[0]]  nms  [0]  yolo_center  [(1231.0, 477.0)]  distances  [16.0312195418814]
#
# step  619  index  0  index_yolo  0
#
# step  620 confidence  0.8155354
#
# step  620 indexes  [[0]]  nms  [0]  yolo_center  [(1240.0, 477.0)]  distances  [18.0]
#
# step  620  index  0  index_yolo  0
#
# step  622 confidence  0.8563444
#
# step  622 indexes  [[0]]  nms  [0]  yolo_center  [(1257.0, 477.0)]  distances  [18.027756377319946]
#
# step  622  index  0  index_yolo  0
#
# step  624 confidence  0.825625
#
# step  624 confidence  0.8066663
#
# step  624 indexes  [[0]]  nms  [0]  yolo_center  [(1271.0, 479.0), (1276.0, 482.0)]  distances  [21.213203435596427]
#
# step  624  index  0  index_yolo  0
#
# step  634 confidence  0.80023235
#
# step  634 indexes  [[0]]  nms  [0]  yolo_center  [(1299.0, 486.0)]  distances  [30.083217912982647]
#
# step  634  index  0  index_yolo  0
#
# step  635 confidence  0.88086593
#
# step  635 indexes  [[0]]  nms  [0]  yolo_center  [(1240.0, 441.0)]  distances  [53.75872022286245]
#
# step  635  index  0  index_yolo  0
#
# step  655 confidence  0.8930103
#
# step  655 indexes  [[0]]  nms  [0]  yolo_center  [(1245.0, 439.0)]  distances  [5.0990195135927845]
#
# step  655  index  0  index_yolo  0
#
# step  656 confidence  0.9159093
#
# step  656 indexes  [[0]]  nms  [0]  yolo_center  [(1246.0, 437.0)]  distances  [5.830951894845301]
#
# step  656  index  0  index_yolo  0
#
# step  657 confidence  0.95308226
#
# step  657 indexes  [[0]]  nms  [0]  yolo_center  [(1248.0, 437.0)]  distances  [5.0990195135927845]
#
# step  657  index  0  index_yolo  0
#
# step  658 confidence  0.9384366
#
# step  658 indexes  [[0]]  nms  [0]  yolo_center  [(1251.0, 438.0)]  distances  [5.385164807134504]
#
# step  658  index  0  index_yolo  0
#
# step  659 confidence  0.96281147
#
# step  659 indexes  [[0]]  nms  [0]  yolo_center  [(1252.0, 438.0)]  distances  [4.123105625617661]
#
# step  659  index  0  index_yolo  0
#
# step  660 confidence  0.9451198
#
# step  660 indexes  [[0]]  nms  [0]  yolo_center  [(1255.0, 438.0)]  distances  [5.0990195135927845]
#
# step  660  index  0  index_yolo  0
#
# step  661 confidence  0.92552924
#
# step  661 indexes  [[0]]  nms  [0]  yolo_center  [(1255.0, 440.0)]  distances  [4.47213595499958]
#
# step  661  index  0  index_yolo  0
#
# step  662 confidence  0.94014734
#
# step  662 indexes  [[0]]  nms  [0]  yolo_center  [(1257.0, 442.0)]  distances  [5.0]
#
# step  662  index  0  index_yolo  0
#
# step  663 confidence  0.85144037
#
# step  663 indexes  [[0]]  nms  [0]  yolo_center  [(1258.0, 442.0)]  distances  [3.1622776601683795]
#
# step  663  index  0  index_yolo  0
#
# step  664 confidence  0.8022501
#
# step  664 indexes  [[0]]  nms  [0]  yolo_center  [(1262.0, 475.0)]  distances  [34.52535300326414]
#
# step  664  index  0  index_yolo  0
#
# step  667 confidence  0.8330089
#
# step  667 indexes  [[0]]  nms  [0]  yolo_center  [(1261.0, 446.0)]  distances  [23.08679276123039]
#
# step  667  index  0  index_yolo  0
#
# step  669 confidence  0.8696608
#
# step  669 indexes  [[0]]  nms  [0]  yolo_center  [(1262.0, 452.0)]  distances  [3.605551275463989]
#
# step  669  index  0  index_yolo  0
#
# step  670 confidence  0.8258315
#
# step  670 indexes  [[0]]  nms  [0]  yolo_center  [(1263.0, 450.0)]  distances  [2.8284271247461903]
#
# step  670  index  0  index_yolo  0
#
# step  675 confidence  0.84687763
#
# step  675 indexes  [[0]]  nms  [0]  yolo_center  [(1266.0, 447.0)]  distances  [3.605551275463989]
#
# step  675  index  0  index_yolo  0
#
# step  676 confidence  0.81810695
#
# step  676 indexes  [[0]]  nms  [0]  yolo_center  [(1268.0, 446.0)]  distances  [3.605551275463989]
#
# step  676  index  0  index_yolo  0
#
# step  680 confidence  0.8037421
#
# step  680 indexes  [[0]]  nms  [0]  yolo_center  [(1269.0, 446.0)]  distances  [2.0]
#
# step  680  index  0  index_yolo  0
# step  681 confidence  0.8109803
#
# step  681 indexes  [[0]]  nms  [0]  yolo_center  [(1269.0, 446.0)]  distances  [2.23606797749979]
#
# step  681  index  0  index_yolo  0
#
# step  683 confidence  0.8072555
#
# step  683 indexes  [[0]]  nms  [0]  yolo_center  [(1269.0, 446.0)]  distances  [2.0]
#
# step  683  index  0  index_yolo  0
#
# step  685 confidence  0.83449435
#
# step  685 indexes  [[0]]  nms  [0]  yolo_center  [(1272.0, 444.0)]  distances  [3.605551275463989]
#
# step  685  index  0  index_yolo  0
#
# step  686 confidence  0.8957893
#
# step  686 indexes  [[0]]  nms  [0]  yolo_center  [(1272.0, 445.0)]  distances  [2.0]
#
# step  686  index  0  index_yolo  0
#
# step  687 confidence  0.93420583
#
# step  687 indexes  [[0]]  nms  [0]  yolo_center  [(1273.0, 444.0)]  distances  [2.0]
#
# step  687  index  0  index_yolo  0
#
# step  688 confidence  0.937246
#
# step  688 indexes  [[0]]  nms  [0]  yolo_center  [(1273.0, 445.0)]  distances  [2.23606797749979]
#
# step  688  index  0  index_yolo  0
#
# step  689 confidence  0.8916701
#
# step  689 indexes  [[0]]  nms  [0]  yolo_center  [(1274.0, 444.0)]  distances  [2.0]
#
# step  689  index  0  index_yolo  0
#
# step  690 confidence  0.8630955
#
# step  690 indexes  [[0]]  nms  [0]  yolo_center  [(1275.0, 445.0)]  distances  [2.0]
#
# step  690  index  0  index_yolo  0
#
# step  691 confidence  0.8573972
#
# step  691 indexes  [[0]]  nms  [0]  yolo_center  [(1277.0, 444.0)]  distances  [2.23606797749979]
#
# step  691  index  0  index_yolo  0
#
# step  692 confidence  0.89672893
#
# step  692 indexes  [[0]]  nms  [0]  yolo_center  [(1276.0, 444.0)]  distances  [1.0]
#
# step  692  index  0  index_yolo  0
#
# step  693 confidence  0.83987516
#
# step  693 indexes  [[0]]  nms  [0]  yolo_center  [(1277.0, 444.0)]  distances  [1.0]
#
# step  693  index  0  index_yolo  0
#
# step  694 confidence  0.8483732
#
# step  694 indexes  [[0]]  nms  [0]  yolo_center  [(1269.0, 440.0)]  distances  [7.615773105863909]
#
# step  694  index  0  index_yolo  0
#
# step  695 confidence  0.8839865
#
# step  695 indexes  [[0]]  nms  [0]  yolo_center  [(1274.0, 445.0)]  distances  [3.1622776601683795]
#
# step  695  index  0  index_yolo  0
#
# step  696 confidence  0.9035588
#
# step  696 indexes  [[0]]  nms  [0]  yolo_center  [(1274.0, 445.0)]  distances  [2.23606797749979]
#
# step  696  index  0  index_yolo  0
#
# step  700 confidence  0.85800636
#
# step  700 indexes  [[0]]  nms  [0]  yolo_center  [(1275.0, 446.0)]  distances  [2.23606797749979]
#
# step  700  index  0  index_yolo  0
#
# step  701 confidence  0.860193
#
# step  701 indexes  [[0]]  nms  [0]  yolo_center  [(1275.0, 446.0)]  distances  [2.23606797749979]
#
# step  701  index  0  index_yolo  0
#
# step  702 confidence  0.8239971
#
# step  702 indexes  [[0]]  nms  [0]  yolo_center  [(1275.0, 446.0)]  distances  [1.4142135623730951]
#
# step  702  index  0  index_yolo  0
#
# step  703 confidence  0.8367872
#
# step  703 indexes  [[0]]  nms  [0]  yolo_center  [(1275.0, 447.0)]  distances  [2.23606797749979]
#
# step  703  index  0  index_yolo  0
#
# step  705 confidence  0.8119184
#
# step  705 indexes  [[0]]  nms  [0]  yolo_center  [(1275.0, 448.0)]  distances  [1.4142135623730951]
#
# step  705  index  0  index_yolo  0
#
# step  707 confidence  0.8145379
#
# step  707 indexes  [[0]]  nms  [0]  yolo_center  [(1277.0, 448.0)]  distances  [2.0]
#
# step  707  index  0  index_yolo  0
#
# step  709 confidence  0.8153192
#
# step  709 indexes  [[0]]  nms  [0]  yolo_center  [(1278.0, 446.0)]  distances  [2.23606797749979]
#
# step  709  index  0  index_yolo  0
#
# step  711 confidence  0.85699105
#
# step  711 indexes  [[0]]  nms  [0]  yolo_center  [(1278.0, 447.0)]  distances  [1.4142135623730951]
#
# step  711  index  0  index_yolo  0
#
# step  712 confidence  0.82812536
#
# step  712 indexes  [[0]]  nms  [0]  yolo_center  [(1278.0, 448.0)]  distances  [2.23606797749979]
#
# step  712  index  0  index_yolo  0
#
# step  713 confidence  0.86849296
#
# step  713 indexes  [[0]]  nms  [0]  yolo_center  [(1278.0, 448.0)]  distances  [1.4142135623730951]
#
# step  713  index  0  index_yolo  0
#
# step  714 confidence  0.845984
#
# step  714 indexes  [[0]]  nms  [0]  yolo_center  [(1278.0, 448.0)]  distances  [1.4142135623730951]
#
# step  714  index  0  index_yolo  0
#
# step  716 confidence  0.8344471
#
# step  716 indexes  [[0]]  nms  [0]  yolo_center  [(1278.0, 449.0)]  distances  [1.4142135623730951]
#
# step  716  index  0  index_yolo  0
#
# step  717 confidence  0.8265963
#
# step  717 indexes  [[0]]  nms  [0]  yolo_center  [(1278.0, 449.0)]  distances  [1.4142135623730951]
#
# step  717  index  0  index_yolo  0
#
# step  718 confidence  0.8389979
#
# step  718 indexes  [[0]]  nms  [0]  yolo_center  [(1279.0, 449.0)]  distances  [1.4142135623730951]
#
# step  718  index  0  index_yolo  0
#
# step  719 confidence  0.8764539
#
# step  719 indexes  [[0]]  nms  [0]  yolo_center  [(1279.0, 449.0)]  distances  [1.4142135623730951]
#
# step  719  index  0  index_yolo  0
#
# step  720 confidence  0.82818526
#
# step  720 indexes  [[0]]  nms  [0]  yolo_center  [(1280.0, 449.0)]  distances  [1.0]
#
# step  720  index  0  index_yolo  0
#
# step  721 confidence  0.8778113
#
# step  721 indexes  [[0]]  nms  [0]  yolo_center  [(1280.0, 447.0)]  distances  [2.23606797749979]
#
# step  721  index  0  index_yolo  0
#
# step  722 confidence  0.8665868
#
# step  722 indexes  [[0]]  nms  [0]  yolo_center  [(1280.0, 448.0)]  distances  [1.4142135623730951]
#
# step  722  index  0  index_yolo  0
#
# step  723 confidence  0.83707374
#
# step  723 indexes  [[0]]  nms  [0]  yolo_center  [(1281.0, 449.0)]  distances  [2.23606797749979]
#
# step  723  index  0  index_yolo  0
#
# step  724 confidence  0.86650085
#
# step  724 indexes  [[0]]  nms  [0]  yolo_center  [(1281.0, 449.0)]  distances  [2.23606797749979]
#
# step  724  index  0  index_yolo  0
#
# step  725 confidence  0.8600774
#
# step  725 indexes  [[0]]  nms  [0]  yolo_center  [(1281.0, 450.0)]  distances  [1.4142135623730951]
#
# step  725  index  0  index_yolo  0
#
# step  726 confidence  0.8465839
#
# step  726 indexes  [[0]]  nms  [0]  yolo_center  [(1281.0, 450.0)]  distances  [1.4142135623730951]
#
# step  726  index  0  index_yolo  0
#
# step  727 confidence  0.89142114
#
# step  727 indexes  [[0]]  nms  [0]  yolo_center  [(1277.0, 483.0)]  distances  [34.36568055487916]
#
# step  727  index  0  index_yolo  0
#
# step  728 confidence  0.86549926
#
# step  728 indexes  [[0]]  nms  [0]  yolo_center  [(1281.0, 452.0)]  distances  [2.23606797749979]
#
# step  728  index  0  index_yolo  0
#
# step  729 confidence  0.8732384
#
# step  729 indexes  [[0]]  nms  [0]  yolo_center  [(1273.0, 447.0)]  distances  [9.899494936611665]
#
# step  729  index  0  index_yolo  0
#
# step  731 confidence  0.88278043
#
# step  731 indexes  [[0]]  nms  [0]  yolo_center  [(1275.0, 448.0)]  distances  [2.23606797749979]
#
# ...
#
# step  846  index  0  index_yolo  0
#
# step  847 confidence  0.9449063
#
# step  847 indexes  [[0]]  nms  [0]  yolo_center  [(1305.0, 455.0)]  distances  [1.0]
#
# step  847  index  0  index_yolo  0
#
# step  848 confidence  0.93901855
#
# step  848 indexes  [[0]]  nms  [0]  yolo_center  [(1306.0, 455.0)]  distances  [1.4142135623730951]
#
# step  848  index  0  index_yolo  0
#
# step  849 confidence  0.9497475
#
# step  849 indexes  [[0]]  nms  [0]  yolo_center  [(1306.0, 455.0)]  distances  [1.0]
#
# step  849  index  0  index_yolo  0
#
# step  850 confidence  0.950692
#
# step  850 indexes  [[0]]  nms  [0]  yolo_center  [(1306.0, 455.0)]  distances  [1.0]
#
# step  850  index  0  index_yolo  0
#
# step  851 confidence  0.94147193
#
# step  851 indexes  [[0]]  nms  [0]  yolo_center  [(1307.0, 455.0)]  distances  [1.4142135623730951]
#
# step  851  index  0  index_yolo  0
# step  852 confidence  0.93859303
#
# step  852 indexes  [[0]]  nms  [0]  yolo_center  [(1307.0, 455.0)]  distances  [1.4142135623730951]
#
# step  852  index  0  index_yolo  0
#
# step  853 confidence  0.89898443
#
# step  853 indexes  [[0]]  nms  [0]  yolo_center  [(1309.0, 455.0)]  distances  [2.0]
#
# step  853  index  0  index_yolo  0
#
# step  854 confidence  0.8884861
#
# step  854 indexes  [[0]]  nms  [0]  yolo_center  [(1310.0, 455.0)]  distances  [1.4142135623730951]
#
# step  854  index  0  index_yolo  0
#
# step  855 confidence  0.872558
#
# step  855 indexes  [[0]]  nms  [0]  yolo_center  [(1310.0, 455.0)]  distances  [1.4142135623730951]
#
# step  855  index  0  index_yolo  0
#
# step  856 confidence  0.8582723
#
# step  856 indexes  [[0]]  nms  [0]  yolo_center  [(1311.0, 455.0)]  distances  [1.0]
#
# step  856  index  0  index_yolo  0
#
# step  857 confidence  0.83459723
#
# step  857 indexes  [[0]]  nms  [0]  yolo_center  [(1312.0, 456.0)]  distances  [1.0]
#
# step  857  index  0  index_yolo  0
#
# step  859 confidence  0.82676655
#
# step  859 indexes  [[0]]  nms  [0]  yolo_center  [(1303.0, 454.0)]  distances  [9.055385138137417]
#
# step  859  index  0  index_yolo  0
#
# step  860 confidence  0.91189724
#
# step  860 indexes  [[0]]  nms  [0]  yolo_center  [(1309.0, 456.0)]  distances  [2.23606797749979]
#
# step  860  index  0  index_yolo  0
#
# step  861 confidence  0.91545343
#
# step  861 indexes  [[0]]  nms  [0]  yolo_center  [(1309.0, 457.0)]  distances  [2.23606797749979]
#
# step  861  index  0  index_yolo  0
#
# step  862 confidence  0.864698
#
# step  862 indexes  [[0]]  nms  [0]  yolo_center  [(1310.0, 457.0)]  distances  [1.0]
#
# step  862  index  0  index_yolo  0
#
# step  863 confidence  0.876923
#
# step  863 indexes  [[0]]  nms  [0]  yolo_center  [(1310.0, 456.0)]  distances  [1.4142135623730951]
#
# step  863  index  0  index_yolo  0
#
# step  864 confidence  0.85426146
#
# step  864 indexes  [[0]]  nms  [0]  yolo_center  [(1310.0, 456.0)]  distances  [1.0]
#
# step  864  index  0  index_yolo  0
#
# step  867 confidence  0.8112379
#
# step  867 indexes  [[0]]  nms  [0]  yolo_center  [(1298.0, 456.0)]  distances  [12.041594578792296]
#
# step  867  index  0  index_yolo  0
#
# step  868 confidence  0.86923426
#
# step  868 indexes  [[0]]  nms  [0]  yolo_center  [(1304.0, 458.0)]  distances  [1.4142135623730951]
#
# step  868  index  0  index_yolo  0
#
# step  869 confidence  0.87618464
#
# step  869 indexes  [[0]]  nms  [0]  yolo_center  [(1300.0, 455.0)]  distances  [2.23606797749979]
#
# step  869  index  0  index_yolo  0
#
# step  870 confidence  0.8957725
#
# step  870 indexes  [[0]]  nms  [0]  yolo_center  [(1300.0, 455.0)]  distances  [1.4142135623730951]
#
# step  870  index  0  index_yolo  0
#
# step  871 confidence  0.94086075
#
# step  871 indexes  [[0]]  nms  [0]  yolo_center  [(1300.0, 456.0)]  distances  [2.23606797749979]
#
# step  871  index  0  index_yolo  0
#
# step  872 confidence  0.9013896
#
# step  872 indexes  [[0]]  nms  [0]  yolo_center  [(1301.0, 457.0)]  distances  [2.23606797749979]
#
# step  872  index  0  index_yolo  0
#
# step  873 confidence  0.8887265
#
# step  873 indexes  [[0]]  nms  [0]  yolo_center  [(1302.0, 457.0)]  distances  [1.4142135623730951]
#
# step  873  index  0  index_yolo  0
#
# step  874 confidence  0.90273184
#
# step  874 indexes  [[0]]  nms  [0]  yolo_center  [(1302.0, 458.0)]  distances  [1.4142135623730951]
#
# step  874  index  0  index_yolo  0
#
# step  875 confidence  0.8720872
#
# step  875 indexes  [[0]]  nms  [0]  yolo_center  [(1303.0, 458.0)]  distances  [2.23606797749979]
#
# step  875  index  0  index_yolo  0
#
# step  876 confidence  0.8877622
#
# step  876 indexes  [[0]]  nms  [0]  yolo_center  [(1304.0, 460.0)]  distances  [3.1622776601683795]
#
# step  876  index  0  index_yolo  0
#
# step  877 confidence  0.85368615
#
# step  877 indexes  [[0]]  nms  [0]  yolo_center  [(1305.0, 459.0)]  distances  [1.4142135623730951]
#
# step  877  index  0  index_yolo  0
#
# step  878 confidence  0.8417287
#
# step  878 indexes  [[0]]  nms  [0]  yolo_center  [(1305.0, 458.0)]  distances  [1.0]
#
# step  878  index  0  index_yolo  0
#
# step  893 confidence  0.8811601
#
# step  893 indexes  [[0]]  nms  [0]  yolo_center  [(1291.0, 457.0)]  distances  [14.035668847618199]
#
# step  893  index  0  index_yolo  0
#
# step  894 confidence  0.85327435
#
# step  894 indexes  [[0]]  nms  [0]  yolo_center  [(1300.0, 460.0)]  distances  [3.1622776601683795]
#
# step  894  index  0  index_yolo  0
#
# step  895 confidence  0.8419702
#
# step  895 indexes  [[0]]  nms  [0]  yolo_center  [(1298.0, 460.0)]  distances  [2.23606797749979]
#
# step  895  index  0  index_yolo  0
#
# step  896 confidence  0.8283314
#
# step  896 indexes  [[0]]  nms  [0]  yolo_center  [(1298.0, 460.0)]  distances  [1.4142135623730951]
#
# step  896  index  0  index_yolo  0
#
# step  901 confidence  0.8286544
#
# step  901 indexes  [[0]]  nms  [0]  yolo_center  [(1289.0, 456.0)]  distances  [9.486832980505138]
#
# step  901  index  0  index_yolo  0
#
# step  902 confidence  0.941364
#
# step  902 indexes  [[0]]  nms  [0]  yolo_center  [(1294.0, 458.0)]  distances  [2.23606797749979]
#
# step  902  index  0  index_yolo  0
#
# step  903 confidence  0.94728863
#
# step  903 indexes  [[0]]  nms  [0]  yolo_center  [(1294.0, 459.0)]  distances  [2.23606797749979]
#
# step  903  index  0  index_yolo  0
#
# step  904 confidence  0.9170611
#
# step  904 indexes  [[0]]  nms  [0]  yolo_center  [(1294.0, 460.0)]  distances  [2.23606797749979]
#
# step  904  index  0  index_yolo  0
#
# step  905 confidence  0.801971
#
# step  905 indexes  [[0]]  nms  [0]  yolo_center  [(1294.0, 460.0)]  distances  [1.4142135623730951]
#
# step  905  index  0  index_yolo  0
#
# step  915 confidence  0.8341463
#
# step  915 indexes  [[0]]  nms  [0]  yolo_center  [(1296.0, 459.0)]  distances  [2.0]
#
# step  915  index  0  index_yolo  0
#
# step  916 confidence  0.8070688
#
# step  916 indexes  [[0]]  nms  [0]  yolo_center  [(1295.0, 458.0)]  distances  [2.0]
#
# step  916  index  0  index_yolo  0
#
# step  917 confidence  0.8138614
#
# step  917 indexes  [[0]]  nms  [0]  yolo_center  [(1296.0, 459.0)]  distances  [2.0]
#
# step  917  index  0  index_yolo  0
#
# step  918 confidence  0.87836486
#
# step  918 indexes  [[0]]  nms  [0]  yolo_center  [(1298.0, 458.0)]  distances  [2.23606797749979]
#
# step  918  index  0  index_yolo  0
#
# step  919 confidence  0.90524614
#
# step  919 indexes  [[0]]  nms  [0]  yolo_center  [(1300.0, 458.0)]  distances  [3.0]
#
# step  919  index  0  index_yolo  0
#
# step  920 confidence  0.8819315
#
# step  920 indexes  [[0]]  nms  [0]  yolo_center  [(1300.0, 457.0)]  distances  [2.0]
#
# step  920  index  0  index_yolo  0
#
# step  921 confidence  0.8529428
#
# step  921 indexes  [[0]]  nms  [0]  yolo_center  [(1301.0, 457.0)]  distances  [2.23606797749979]
#
# step  921  index  0  index_yolo  0
#
# step  922 confidence  0.8719325
#
# step  922 indexes  [[0]]  nms  [0]  yolo_center  [(1302.0, 458.0)]  distances  [3.605551275463989]
#
# step  922  index  0  index_yolo  0
#
# step  923 confidence  0.8803369
#
# step  923 indexes  [[0]]  nms  [0]  yolo_center  [(1303.0, 457.0)]  distances  [2.23606797749979]
#
# step  923  index  0  index_yolo  0
#
# step  924 confidence  0.95794207
#
# step  924 indexes  [[0]]  nms  [0]  yolo_center  [(1289.0, 457.0)]  distances  [13.0]
#
# step  924  index  0  index_yolo  0
#
# step  925 confidence  0.9196447
#
# step  925 indexes  [[0]]  nms  [0]  yolo_center  [(1298.0, 457.0)]  distances  [2.23606797749979]
#
# step  925  index  0  index_yolo  0
#
# step  926 confidence  0.86293983
#
# step  926 indexes  [[0]]  nms  [0]  yolo_center  [(1296.0, 456.0)]  distances  [2.23606797749979]
#
# step  926  index  0  index_yolo  0
#
# step  927 confidence  0.8622219
#
# step  927 indexes  [[0]]  nms  [0]  yolo_center  [(1298.0, 457.0)]  distances  [2.23606797749979]
#
# step  927  index  0  index_yolo  0
#
# step  928 confidence  0.86238354
#
# step  928 indexes  [[0]]  nms  [0]  yolo_center  [(1299.0, 456.0)]  distances  [2.0]
#
# step  928  index  0  index_yolo  0
#
# step  929 confidence  0.8503743
#
# step  929 indexes  [[0]]  nms  [0]  yolo_center  [(1300.0, 456.0)]  distances  [2.0]
#
# step  929  index  0  index_yolo  0
#
# step  930 confidence  0.8611385
#
# step  930 indexes  [[0]]  nms  [0]  yolo_center  [(1300.0, 457.0)]  distances  [2.23606797749979]
#
# step  930  index  0  index_yolo  0
# step  931 confidence  0.8882434
#
# step  931 indexes  [[0]]  nms  [0]  yolo_center  [(1286.0, 456.0)]  distances  [12.041594578792296]
#
# step  931  index  0  index_yolo  0
#
# step  932 confidence  0.834198
#
# step  932 indexes  [[0]]  nms  [0]  yolo_center  [(1296.0, 457.0)]  distances  [2.23606797749979]
#
# step  932  index  0  index_yolo  0
#
# step  933 confidence  0.82878226
#
# step  933 indexes  [[0]]  nms  [0]  yolo_center  [(1296.0, 457.0)]  distances  [2.8284271247461903]
#
# step  933  index  0  index_yolo  0
#
# step  934 confidence  0.8124289
#
# step  934 indexes  [[0]]  nms  [0]  yolo_center  [(1298.0, 457.0)]  distances  [2.23606797749979]
#
# step  934  index  0  index_yolo  0
#
# step  935 confidence  0.8582415
#
# step  935 indexes  [[0]]  nms  [0]  yolo_center  [(1284.0, 455.0)]  distances  [13.038404810405298]
#
# step  935  index  0  index_yolo  0
#
# step  941 confidence  0.81467915
#
# step  941 indexes  [[0]]  nms  [0]  yolo_center  [(1285.0, 458.0)]  distances  [4.47213595499958]
#
# step  941  index  0  index_yolo  0
#
# step  943 confidence  0.8117131
#
# step  943 indexes  [[0]]  nms  [0]  yolo_center  [(1286.0, 459.0)]  distances  [2.23606797749979]
#
# step  943  index  0  index_yolo  0
#
# step  944 confidence  0.80924773
#
# step  944 indexes  [[0]]  nms  [0]  yolo_center  [(1287.0, 459.0)]  distances  [2.0]
#
# step  944  index  0  index_yolo  0
#
# step  945 confidence  0.8492544
#
# step  945 indexes  [[0]]  nms  [0]  yolo_center  [(1288.0, 459.0)]  distances  [2.0]
#
# step  945  index  0  index_yolo  0
#
# step  946 confidence  0.8573453
#
# step  946 indexes  [[0]]  nms  [0]  yolo_center  [(1289.0, 458.0)]  distances  [2.23606797749979]
#
# step  946  index  0  index_yolo  0
#
# step  947 confidence  0.8986061
#
# step  947 indexes  [[0]]  nms  [0]  yolo_center  [(1290.0, 458.0)]  distances  [2.0]
#
# step  947  index  0  index_yolo  0
#
# step  948 confidence  0.89518726
#
# step  948 indexes  [[0]]  nms  [0]  yolo_center  [(1292.0, 458.0)]  distances  [2.23606797749979]
#
# step  948  index  0  index_yolo  0
#
# step  949 confidence  0.8716366
#
# step  949 indexes  [[0]]  nms  [0]  yolo_center  [(1294.0, 457.0)]  distances  [3.1622776601683795]
#
# step  949  index  0  index_yolo  0
#
# step  950 confidence  0.89570946
#
# step  950 indexes  [[0]]  nms  [0]  yolo_center  [(1280.0, 456.0)]  distances  [12.165525060596439]
#
# step  950  index  0  index_yolo  0
#
# step  951 confidence  0.87094283
#
# step  951 indexes  [[0]]  nms  [0]  yolo_center  [(1290.0, 457.0)]  distances  [3.0]
#
# step  951  index  0  index_yolo  0
#
# step  952 confidence  0.9033883
#
# step  952 indexes  [[0]]  nms  [0]  yolo_center  [(1290.0, 457.0)]  distances  [3.1622776601683795]
#
# step  952  index  0  index_yolo  0
#
# step  953 confidence  0.91468924
#
# step  953 indexes  [[0]]  nms  [0]  yolo_center  [(1276.0, 456.0)]  distances  [12.041594578792296]
#
# step  953  index  0  index_yolo  0
#
# step  954 confidence  0.8376027
#
# step  954 indexes  [[0]]  nms  [0]  yolo_center  [(1285.0, 458.0)]  distances  [3.605551275463989]
#
# step  954  index  0  index_yolo  0
#
# step  955 confidence  0.83760023
#
# step  955 indexes  [[0]]  nms  [0]  yolo_center  [(1286.0, 457.0)]  distances  [3.0]
#
# step  955  index  0  index_yolo  0
#
# step  956 confidence  0.89493465
#
# step  956 indexes  [[0]]  nms  [0]  yolo_center  [(1288.0, 458.0)]  distances  [3.0]
#
# step  956  index  0  index_yolo  0
#
# step  957 confidence  0.92705685
#
# step  957 indexes  [[0]]  nms  [0]  yolo_center  [(1273.0, 457.0)]  distances  [13.038404810405298]
#
# step  957  index  0  index_yolo  0
#
# step  958 confidence  0.8805068
#
# step  958 indexes  [[0]]  nms  [0]  yolo_center  [(1285.0, 457.0)]  distances  [3.0]
#
# step  958  index  0  index_yolo  0
#
# step  959 confidence  0.8734512
#
# step  959 indexes  [[0]]  nms  [0]  yolo_center  [(1284.0, 457.0)]  distances  [2.0]
#
# step  959  index  0  index_yolo  0
#
# step  960 confidence  0.86771125
#
# step  960 indexes  [[0]]  nms  [0]  yolo_center  [(1286.0, 457.0)]  distances  [3.1622776601683795]
#
# step  960  index  0  index_yolo  0
#
# step  961 confidence  0.8743545
#
# step  961 indexes  [[0]]  nms  [0]  yolo_center  [(1287.0, 457.0)]  distances  [3.1622776601683795]
#
# step  961  index  0  index_yolo  0
#
# step  962 confidence  0.91078496
#
# step  962 indexes  [[0]]  nms  [0]  yolo_center  [(1274.0, 455.0)]  distances  [12.165525060596439]
#
# step  962  index  0  index_yolo  0
#
# step  963 confidence  0.8823362
#
# step  963 indexes  [[0]]  nms  [0]  yolo_center  [(1283.0, 457.0)]  distances  [2.23606797749979]
#
# step  963  index  0  index_yolo  0
#
# step  964 confidence  0.8694203
#
# step  964 indexes  [[0]]  nms  [0]  yolo_center  [(1284.0, 456.0)]  distances  [3.0]
#
# step  964  index  0  index_yolo  0
#
# step  966 confidence  0.8601457
#
# step  966 indexes  [[0]]  nms  [0]  yolo_center  [(1287.0, 457.0)]  distances  [3.1622776601683795]
#
# step  966  index  0  index_yolo  0
#
# step  967 confidence  0.8291213
#
# step  967 indexes  [[0]]  nms  [0]  yolo_center  [(1287.0, 457.0)]  distances  [2.23606797749979]
#
# step  967  index  0  index_yolo  0
#
# step  968 confidence  0.86508083
#
# step  968 indexes  [[0]]  nms  [0]  yolo_center  [(1274.0, 455.0)]  distances  [13.152946437965905]
#
# step  968  index  0  index_yolo  0
#
# step  969 confidence  0.88275427
#
# step  969 indexes  [[0]]  nms  [0]  yolo_center  [(1284.0, 455.0)]  distances  [3.1622776601683795]
#
# step  969  index  0  index_yolo  0
#
# step  970 confidence  0.8811272
#
# step  970 indexes  [[0]]  nms  [0]  yolo_center  [(1285.0, 456.0)]  distances  [3.0]
#
# step  970  index  0  index_yolo  0
#
# step  972 confidence  0.8525758
#
# step  972 indexes  [[0]]  nms  [0]  yolo_center  [(1270.0, 454.0)]  distances  [14.035668847618199]
#
# step  972  index  0  index_yolo  0
#
# step  974 confidence  0.82774764
#
# step  974 indexes  [[0]]  nms  [0]  yolo_center  [(1277.0, 457.0)]  distances  [3.605551275463989]
#
# step  974  index  0  index_yolo  0
#
# step  975 confidence  0.8647315
#
# step  975 indexes  [[0]]  nms  [0]  yolo_center  [(1277.0, 456.0)]  distances  [2.0]
#
# step  975  index  0  index_yolo  0
#
# step  976 confidence  0.89492744
#
# step  976 indexes  [[0]]  nms  [0]  yolo_center  [(1278.0, 457.0)]  distances  [2.23606797749979]
#
# step  976  index  0  index_yolo  0
#
# step  977 confidence  0.8998916
#
# step  977 indexes  [[0]]  nms  [0]  yolo_center  [(1278.0, 456.0)]  distances  [2.0]
#
# step  977  index  0  index_yolo  0
#
# step  978 confidence  0.89230895
#
# step  978 indexes  [[0]]  nms  [0]  yolo_center  [(1281.0, 455.0)]  distances  [3.0]
#
# step  978  index  0  index_yolo  0
#
# step  979 confidence  0.8690229
#
# step  979 indexes  [[0]]  nms  [0]  yolo_center  [(1282.0, 456.0)]  distances  [3.1622776601683795]
#
# step  979  index  0  index_yolo  0
#
# step  980 confidence  0.84776616
#
# step  980 indexes  [[0]]  nms  [0]  yolo_center  [(1283.0, 456.0)]  distances  [2.23606797749979]
#
# step  980  index  0  index_yolo  0

# %%
prog_duration= time.time() - start_time
prog_duration
# Out:
# 394.99127984046936

# %%
prog_duration/60
# Out:
# 6.583187997341156

# %%
prog_duration/(60*Tot)
# Out:
# 6.583187997341156

# %%
sum(n_resampl_l)/Tot
# Out:
# 402.0

# %%
len(BB_l),len(xy_est_l),len(BB_avg),len(xy_est_avg),len(particles_avg),len(anchor_avg)
# Out:
# (980, 980, 1, 1, 1, 1)

# %%
sum(yolo_det_l)/Tot
# Out:
# 444.0

# %%
BB_l_avg=[] 
BB_avg=np.array(BB_avg)
BB_l_avg=np.sum(BB_avg,0)/Tot

# %%
xy_est_l_avg=[] 
xy_est_avg=np.array(xy_est_avg)
xy_est_l_avg=np.sum(xy_est_avg,0)/Tot
xy_est_l_avg
# Out:
# array([[1143.,  471.],
#        [1270.,  404.],
#        [1327.,  366.],
#        ...,
#        [1279.,  455.],
#        [1281.,  455.],
#        [1281.,  455.]])

# %%
ROI_l_avg=[] 
ROI_avg=np.array(ROI_avg)
ROI_l_avg=np.sum(ROI_avg,0)/Tot

# %%
particles_l_avg=[] 
particles_avg=np.array(particles_avg)
particles_l_avg=np.sum(particles_avg,0)/Tot

# %%
anchor_l_avg=[] 
anchor_avg=np.array(anchor_avg)
anchor_l_avg=np.sum(anchor_avg,0)/Tot
anchor_l_avg
# Out:
# array([[1250.,  350.],
#        [1291.,  358.],
#        [1319.,  364.],
#        ...,
#        [1278.,  455.],
#        [1279.,  455.],
#        [1281.,  455.]])

# %%
#xy_est_l

# %%
#BB_l

# %%
np.save(path+'xy_data3.npy',np.array(xy_est_l_avg))
np.save(path+'BB_data3.npy',np.array(BB_l_avg))
np.save(path+'ROI_data3.npy',np.array(ROI_l_avg))
np.save(path+'part_data3.npy',np.array(particles_l_avg))
np.save(path+'anchor_data3.npy',np.array(anchor_l_avg))
